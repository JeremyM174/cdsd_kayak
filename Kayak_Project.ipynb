# %% [markdown]
# # Goal reminder 🎯
#
# As the project has just started, your team doesn't have any data that can be used to create this application. Therefore, your job will be to:
#
# * Scrape data from destinations
# * Get weather data from each destination
# * Get hotels' info about each destination
# * Store all the information above in a data lake
# * Extract, transform and load cleaned data from your datalake to a data warehouse
#
# ### Scope of this project 🖼️
#
# Marketing team wants to focus first on the best cities to travel to in France. According <a href="https://one-week-in.com/35-cities-to-visit-in-france/" target="_blank">One Week In.com</a> here are the top-35 cities to visit in France:
#
# ```python
# ["Mont Saint Michel", "St Malo", "Bayeux", "Le Havre", "Rouen", "Paris", "Amiens", "Lille", "Strasbourg", "Chateau du Haut Koenigsbourg", "Colmar", "Eguisheim", "Besancon", "Dijon", "Annecy", "Grenoble", "Lyon", "Gorges du Verdon", "Bormes les Mimosas", "Cassis", "Marseille", "Aix en Provence", "Avignon", "Uzes", "Nimes", "Aigues Mortes", "Saintes Maries de la mer", "Collioure", "Carcassonne", "Ariege", "Toulouse", "Montauban", "Biarritz", "Bayonne", "La Rochelle"]
# ```
#
# Your team should focus **only on the above cities for your project**.

# %% [markdown]
# # Basic information
#
# First things first: let's load the libraries we will be using, as well as the private data to run our tools such as AWS' and variables to work on.
#
# We used Anaconda as our environment manager. You may already have one to run this notebook but it is highly recommended you create a new environment following these instructions:
#
# 1. Run Anaconda prompt
# 2. `cd` to the working directory where this notebook is located (..\cdsd_kayak)
#     * If you cannot remember where you downloaded the project, run `cd (ls C:\Users\ cdsd_kayak -Recurse -Directory).FullName`
#     * This simple command assumes it was downloaded on your C:\ drive and will **not** handle exceptions!
# 3. Install our environment: `conda env create -n M174_kayak --file=kayak_project_environment.yaml`
# 4. Activate it: `conda activate M174_kayak`
# 5. Since Anaconda doesn't support METEO France's API, if it failed running the pip command, you may have to install it with `pip install meteofrance-api`
# 6. Your new environment is ready for use!
#
# If you came back here because of the spiders, here is a [convenient link](#getting-20-hotels-urls-per-location) back to this part. Otherwise, on to the next cell!

# %%
import pandas as pd 
import numpy as np 
import plotly.express as px

from geopy.geocoders import Nominatim
from meteofrance_api import MeteoFranceClient
from datetime import datetime

import json, requests, os, dotenv, boto3

from sqlalchemy import create_engine, text

# %%
holiday_places = ["Mont Saint Michel", "St Malo", "Bayeux", "Le Havre", "Rouen", "Paris", "Amiens", "Lille", "Strasbourg", 
                  "Chateau du Haut Koenigsbourg", "Colmar", "Eguisheim", "Besancon", "Dijon", "Annecy", "Grenoble", "Lyon", "Gorges du Verdon", 
                  "Bormes les Mimosas", "Cassis", "Marseille", "Aix en Provence", "Avignon", "Uzes", "Nimes", "Aigues Mortes", 
                  "Saintes Maries de la mer", "Collioure", "Carcassonne", "Ariege", "Toulouse", "Montauban", "Biarritz", "Bayonne", "La Rochelle"]

len(holiday_places)
# Out:
# 35

# %% [markdown]
# ### Environment variables setup
#
# These confidential variables must be set up to run the online parts of this notebook. Please refer to the `.env_example.txt` file for a template & instructions.
#
# For convenience if you were near the end of the notebook, here is a [link back](#pushing-our-final-dataframe-to-s3) to the part that refers the most to these confidential variables.

# %%
dotenv.load_dotenv()

HERE_api_key = os.getenv("HERE_api_key")    #requires your registering with a HERE account
HERE_api_url = 'https://geocode.search.hereapi.com/v1/'

AWS_id = os.getenv("AWS_ACCESS_KEY_ID")     #all of these will be found under your AWS "IAM" service
AWS_secret_key = os.getenv("AWS_SECRET_ACCESS_KEY")
S3_bucket = os.getenv("S3_BUCKET_NAME")
S3_uri = os.getenv("S3_BUCKET_URI")

neonDB = os.getenv("SQL_NEONDB_URI")        #finally, this one requires setting up your own account & neonDB project

# %% [markdown]
# # Getting GPS coordinates
#
# We will first initialize Nominatim, while raising its timeout value since it can take a few seconds to return a result.
#
# Then we'll iterate on our places' coordinates:

# %%
geolocator = Nominatim(timeout=10, user_agent="weather_app")

# %%
for place in holiday_places:
    location = geolocator.geocode(f'{place}, France')
    if location:
        print(f"{place} → lat: {location.latitude}, lon: {location.longitude}")
    else:
        print(f"Unable to find {place}")
# Out:
# Mont Saint Michel → lat: 48.6359541, lon: -1.51146
# St Malo → lat: 48.649518, lon: -2.0260409
# Bayeux → lat: 49.2764624, lon: -0.7024738
# Le Havre → lat: 49.4938975, lon: 0.1079732
# Rouen → lat: 49.4404591, lon: 1.0939658
# Paris → lat: 48.8588897, lon: 2.320041
# Amiens → lat: 49.8941708, lon: 2.2956951
# Lille → lat: 50.6365654, lon: 3.0635282
# Strasbourg → lat: 48.584614, lon: 7.7507127
# Chateau du Haut Koenigsbourg → lat: 48.2494107, lon: 7.3443202
# Colmar → lat: 48.0777517, lon: 7.3579641
# Eguisheim → lat: 48.0447968, lon: 7.3079618
# Besancon → lat: 47.2380222, lon: 6.0243622
# Dijon → lat: 47.3215806, lon: 5.0414701
# Annecy → lat: 45.8992348, lon: 6.1288847
# Grenoble → lat: 45.1875602, lon: 5.7357819
# Lyon → lat: 45.7578137, lon: 4.8320114
# Gorges du Verdon → lat: 43.7496562, lon: 6.3285616
# Bormes les Mimosas → lat: 43.1506968, lon: 6.3419285
# Cassis → lat: 43.2140359, lon: 5.5396318
# Marseille → lat: 43.2961743, lon: 5.3699525
# Aix en Provence → lat: 43.5298424, lon: 5.4474738
# Avignon → lat: 43.9492493, lon: 4.8059012
# Uzes → lat: 44.0121279, lon: 4.4196718
# Nimes → lat: 43.8374249, lon: 4.3600687
# Aigues Mortes → lat: 43.5661521, lon: 4.19154
# Saintes Maries de la mer → lat: 43.4515922, lon: 4.4277202
# Collioure → lat: 42.52505, lon: 3.0831554
# Carcassonne → lat: 43.2130358, lon: 2.3491069
# Ariege → lat: 42.9455368, lon: 1.4065544
# Toulouse → lat: 43.6044638, lon: 1.4442433
# Montauban → lat: 44.0175835, lon: 1.3549991
# Biarritz → lat: 43.4832523, lon: -1.5592776
# Bayonne → lat: 43.4945144, lon: -1.4736657
# La Rochelle → lat: 46.159732, lon: -1.1515951

# %% [markdown]
# # Getting weather data
#
# Next for the weather data, we'll first run a little test using the French weather service Meteo France:

# %%
client = MeteoFranceClient()

# %%
def get_forecast_by_city(city_name):
    location = geolocator.geocode(f'{city_name}, France') #recovering Nominatim's GPS coordinates
    if not location:
        return city_name, None

    forecast = client.get_forecast(location.latitude, location.longitude)
    
    daily = forecast.daily_forecast[:2] #forecast recovery for the next two days
    id_place = forecast.position['insee'] #unique id based on France's national institute for statistics
    return city_name, daily, id_place

# %%
for place in holiday_places:
    city, daily_forecast, id_place = get_forecast_by_city(f'{place}, France')
    if daily_forecast:
        print(f"Forecast for {city} :")
        print(f'INSEE id {id_place} \n')
        location = geolocator.geocode(f'{place}, France')
        print(f"→ lat: {location.latitude}, lon: {location.longitude} \n")
        for day in daily_forecast:
            date = datetime.fromtimestamp(day["dt"]).strftime("%Y-%m-%d")
            tmin = day["T"]["min"]
            tmax = day["T"]["max"]
            print(f" - {date}: {tmin}°C → {tmax}°C")
        print()
    else:
        print(f"!!! Error encountered for {city} !!!")
# Out:
# Forecast for Mont Saint Michel, France :
# INSEE id 5035351
#
# → lat: 48.6359541, lon: -1.51146
#
#  - 2025-11-13: 12.5°C → 17.2°C
#  - 2025-11-14: 13.4°C → 18.2°C
#
# Forecast for St Malo, France :
# INSEE id 3528885
#
# → lat: 48.649518, lon: -2.0260409
#
#  - 2025-11-13: 13.6°C → 17.4°C
#  - 2025-11-14: 14.6°C → 18.7°C
#
# Forecast for Bayeux, France :
# INSEE id 140470
#
# → lat: 49.2764624, lon: -0.7024738
#
#  - 2025-11-13: 13.4°C → 18.1°C
#  - 2025-11-14: 13.9°C → 19°C
#
# Forecast for Le Havre, France :
# INSEE id 763510
#
# → lat: 49.4938975, lon: 0.1079732
#
#  - 2025-11-13: 13.1°C → 18.1°C
#  - 2025-11-14: 12.5°C → 19.5°C
#
# Forecast for Rouen, France :
# INSEE id 765400
#
# → lat: 49.4404591, lon: 1.0939658
#
#  - 2025-11-13: 9.9°C → 17.7°C
#  - 2025-11-14: 11.4°C → 19.6°C
#
# Forecast for Paris, France :
# INSEE id 751070
#
# → lat: 48.8588897, lon: 2.320041
#
#  - 2025-11-13: 11.5°C → 17.7°C
#  - 2025-11-14: 13.2°C → 20.1°C
#
# Forecast for Amiens, France :
# INSEE id 800210
#
# → lat: 49.8941708, lon: 2.2956951
#
#  - 2025-11-13: 12.2°C → 17.1°C
#  - 2025-11-14: 11.5°C → 18°C
#
# Forecast for Lille, France :
# INSEE id 593500
#
# → lat: 50.6365654, lon: 3.0635282
#
#  - 2025-11-13: 12.4°C → 16.4°C
#  - 2025-11-14: 11.6°C → 17.7°C
#
# Forecast for Strasbourg, France :
# INSEE id 674820
#
# → lat: 48.584614, lon: 7.7507127
#
#  - 2025-11-13: 5.5°C → 17.9°C
#  - 2025-11-14: 8.1°C → 16.5°C
#
# Forecast for Chateau du Haut Koenigsbourg, France :
# INSEE id 682800
#
# → lat: 48.2494107, lon: 7.3443202
#
#  - 2025-11-13: 5.5°C → 18.1°C
#  - 2025-11-14: 8.2°C → 18.2°C
#
# Forecast for Colmar, France :
# INSEE id 680660
#
# → lat: 48.0777517, lon: 7.3579641
#
#  - 2025-11-13: 6.1°C → 19°C
#  - 2025-11-14: 9.2°C → 21.5°C
#
# Forecast for Eguisheim, France :
# INSEE id 680780
#
# → lat: 48.0447968, lon: 7.3079618
#
#  - 2025-11-13: 8.4°C → 19.6°C
#  - 2025-11-14: 9.7°C → 20.5°C
#
# Forecast for Besancon, France :
# INSEE id 250560
#
# → lat: 47.2380222, lon: 6.0243622
#
#  - 2025-11-13: 6.1°C → 21.5°C
#  - 2025-11-14: 6.2°C → 19.1°C
#
# Forecast for Dijon, France :
# INSEE id 212310
#
# → lat: 47.3215806, lon: 5.0414701
#
#  - 2025-11-13: 11.1°C → 20.2°C
#  - 2025-11-14: 12.1°C → 20.6°C
#
# Forecast for Annecy, France :
# INSEE id 740100
#
# → lat: 45.8992348, lon: 6.1288847
#
#  - 2025-11-13: 2.1°C → 15.6°C
#  - 2025-11-14: 3.6°C → 15.7°C
#
# Forecast for Grenoble, France :
# INSEE id 381850
#
# → lat: 45.1875602, lon: 5.7357819
#
#  - 2025-11-13: 9.1°C → 23.7°C
#  - 2025-11-14: 8.1°C → 24.5°C
#
# Forecast for Lyon, France :
# INSEE id 691230
#
# → lat: 45.7578137, lon: 4.8320114
#
#  - 2025-11-13: 15.7°C → 20°C
#  - 2025-11-14: 15.2°C → 19.6°C
#
# Forecast for Gorges du Verdon, France :
# INSEE id 041440
#
# → lat: 43.7496562, lon: 6.3285616
#
#  - 2025-11-13: 2.6°C → 16.1°C
#  - 2025-11-14: 6.9°C → 15.5°C
#
# Forecast for Bormes les Mimosas, France :
# INSEE id 830190
#
# → lat: 43.1506968, lon: 6.3419285
#
#  - 2025-11-13: 11.9°C → 19.9°C
#  - 2025-11-14: 13.6°C → 20.4°C
#
# Forecast for Cassis, France :
# INSEE id 130220
#
# → lat: 43.2140359, lon: 5.5396318
#
#  - 2025-11-13: 14.6°C → 21.5°C
#  - 2025-11-14: 16.2°C → 22.1°C
#
# Forecast for Marseille, France :
# INSEE id 130550
#
# → lat: 43.2961743, lon: 5.3699525
#
#  - 2025-11-13: 14.9°C → 21.4°C
#  - 2025-11-14: 16.7°C → 21.1°C
#
# Forecast for Aix en Provence, France :
# INSEE id 130010
#
# → lat: 43.5298424, lon: 5.4474738
#
#  - 2025-11-13: 9.1°C → 20.7°C
#  - 2025-11-14: 13.2°C → 20.1°C
#
# Forecast for Avignon, France :
# INSEE id 840070
#
# → lat: 43.9492493, lon: 4.8059012
#
#  - 2025-11-13: 8.7°C → 21°C
#  - 2025-11-14: 9.1°C → 21.4°C
#
# Forecast for Uzes, France :
# INSEE id 303340
#
# → lat: 44.0121279, lon: 4.4196718
#
#  - 2025-11-13: 10°C → 19.9°C
#  - 2025-11-14: 9.5°C → 20.6°C
#
# Forecast for Nimes, France :
# INSEE id 301890
#
# → lat: 43.8374249, lon: 4.3600687
#
#  - 2025-11-13: 13.5°C → 20.6°C
#  - 2025-11-14: 12.1°C → 20.9°C
#
# Forecast for Aigues Mortes, France :
# INSEE id 300030
#
# → lat: 43.5661521, lon: 4.19154
#
#  - 2025-11-13: 12.9°C → 20.5°C
#  - 2025-11-14: 16°C → 20.6°C
#
# Forecast for Saintes Maries de la mer, France :
# INSEE id 1309651
#
# → lat: 43.4515922, lon: 4.4277202
#
#  - 2025-11-13: 14°C → 19.4°C
#  - 2025-11-14: 16.2°C → 19.6°C
#
# Forecast for Collioure, France :
# INSEE id 660530
#
# → lat: 42.52505, lon: 3.0831554
#
#  - 2025-11-13: 16.7°C → 20.6°C
#  - 2025-11-14: 16.4°C → 21.4°C
#
# Forecast for Carcassonne, France :
# INSEE id 110690
#
# → lat: 43.2130358, lon: 2.3491069
#
#  - 2025-11-13: 16.5°C → 20.2°C
#  - 2025-11-14: 16.1°C → 20°C
#
# Forecast for Ariege, France :
# INSEE id 091960
#
# → lat: 42.9455368, lon: 1.4065544
#
#  - 2025-11-13: 12.1°C → 20.5°C
#  - 2025-11-14: 12.6°C → 18.7°C
#
# Forecast for Toulouse, France :
# INSEE id 315550
#
# → lat: 43.6044638, lon: 1.4442433
#
#  - 2025-11-13: 17.2°C → 21.1°C
#  - 2025-11-14: 16.2°C → 21.1°C
#
# Forecast for Montauban, France :
# INSEE id 821210
#
# → lat: 44.0175835, lon: 1.3549991
#
#  - 2025-11-13: 16.6°C → 22.1°C
#  - 2025-11-14: 16.5°C → 22°C
#
# Forecast for Biarritz, France :
# INSEE id 6412251
#
# → lat: 43.4832523, lon: -1.5592776
#
#  - 2025-11-13: 21.1°C → 25.5°C
#  - 2025-11-14: 18.5°C → 23.5°C
#
# Forecast for Bayonne, France :
# INSEE id 641020
#
# → lat: 43.4945144, lon: -1.4736657
#
#  - 2025-11-13: 20.7°C → 26.5°C
#  - 2025-11-14: 18.1°C → 24.6°C
#
# Forecast for La Rochelle, France :
# INSEE id 173000
#
# → lat: 46.159732, lon: -1.1515951
#
#  - 2025-11-13: 14.1°C → 20.5°C
#  - 2025-11-14: 15.4°C → 19.1°C

# %%
daily_forecast
# Out:
# [{'dt': 1762992000,
#   'T': {'min': 14.1, 'max': 20.5, 'sea': None},
#   'humidity': {'min': 65, 'max': 85},
#   'precipitation': {'24h': 0},
#   'uv': 1,
#   'weather12H': {'icon': 'p3bisj', 'desc': 'Couvert'},
#   'sun': {'rise': 1763017323, 'set': 1763051706}},
#  {'dt': 1763078400,
#   'T': {'min': 15.4, 'max': 19.1, 'sea': None},
#   'humidity': {'min': 70, 'max': 90},
#   'precipitation': {'24h': 1.1},
#   'uv': 1,
#   'weather12H': {'icon': 'p12j', 'desc': 'Pluie faible'},
#   'sun': {'rise': 1763103808, 'set': 1763138039}}]

# %% [markdown]
# The variable printed above returns a lot of interesting informations we may use for our objective. Let's extract those:

# %%
for place in holiday_places:
    city, daily_forecast, id_place = get_forecast_by_city(f'{place}, France')
    if daily_forecast:
        print(f"=== Forecast for {city} :")
        location = geolocator.geocode(f'{place}, France')
        print(f"→ lat: {location.latitude}, lon: {location.longitude} \n")
        for day in daily_forecast:
            date = datetime.fromtimestamp(day["dt"]).strftime("%Y-%m-%d")
            tmin = day["T"]["min"]
            tmax = day["T"]["max"]
            rainfall = day['precipitation']['24h']
            uv = day['uv']
            weather = day['weather12H']['desc']
            id = day['weather12H']['desc']
            print(f" - {date}: {tmin}°C → {tmax}°C \n rainfall => {rainfall} uv => {uv} weather => {weather}")
        print()
    else:
        print(f"!!! Error encountered for {city} !!!")
# Out:
# === Forecast for Mont Saint Michel, France :
# → lat: 48.6359541, lon: -1.51146
#
#  - 2025-11-13: 12.5°C → 17.2°C
#  rainfall => 0.6 uv => 1 weather => Pluie faible
#  - 2025-11-14: 13.4°C → 18.2°C
#  rainfall => 2.3 uv => 1 weather => Pluie faible
#
# === Forecast for St Malo, France :
# → lat: 48.649518, lon: -2.0260409
#
#  - 2025-11-13: 13.6°C → 17.4°C
#  rainfall => 0.4 uv => 1 weather => Pluie faible
#  - 2025-11-14: 14.6°C → 18.7°C
#  rainfall => 2.8 uv => 1 weather => Pluie faible
#
# === Forecast for Bayeux, France :
# → lat: 49.2764624, lon: -0.7024738
#
#  - 2025-11-13: 13.4°C → 18.1°C
#  rainfall => 0.1 uv => 1 weather => Couvert
#  - 2025-11-14: 13.9°C → 19°C
#  rainfall => 0.1 uv => 1 weather => Couvert
#
# === Forecast for Le Havre, France :
# → lat: 49.4938975, lon: 0.1079732
#
#  - 2025-11-13: 13.1°C → 18.1°C
#  rainfall => 0.5 uv => 1 weather => Pluie faible
#  - 2025-11-14: 12.5°C → 19.5°C
#  rainfall => 0.6 uv => 1 weather => Pluie faible
#
# === Forecast for Rouen, France :
# → lat: 49.4404591, lon: 1.0939658
#
#  - 2025-11-13: 9.9°C → 17.7°C
#  rainfall => 1.7 uv => 0 weather => Pluie faible
#  - 2025-11-14: 11.4°C → 19.6°C
#  rainfall => 0.5 uv => 1 weather => Pluie faible
#
# === Forecast for Paris, France :
# → lat: 48.8588897, lon: 2.320041
#
#  - 2025-11-13: 11.5°C → 17.7°C
#  rainfall => 0 uv => 1 weather => Couvert
#  - 2025-11-14: 13.2°C → 20.1°C
#  rainfall => 0 uv => 1 weather => Couvert
#
# === Forecast for Amiens, France :
# → lat: 49.8941708, lon: 2.2956951
#
#  - 2025-11-13: 12.2°C → 17.1°C
#  rainfall => 0 uv => 1 weather => Couvert
#  - 2025-11-14: 11.5°C → 18°C
#  rainfall => 0.3 uv => 1 weather => Pluie faible
#
# === Forecast for Lille, France :
# → lat: 50.6365654, lon: 3.0635282
#
#  - 2025-11-13: 12.4°C → 16.4°C
#  rainfall => 0.6 uv => 0 weather => Couvert
#  - 2025-11-14: 11.6°C → 17.7°C
#  rainfall => 0.6 uv => 1 weather => Pluie faible
#
# === Forecast for Strasbourg, France :
# → lat: 48.584614, lon: 7.7507127
#
#  - 2025-11-13: 5.5°C → 17.9°C
#  rainfall => 0 uv => 1 weather => Eclaircies
#  - 2025-11-14: 8.1°C → 16.5°C
#  rainfall => 0.1 uv => 1 weather => Ciel voilé
#
# === Forecast for Chateau du Haut Koenigsbourg, France :
# → lat: 48.2494107, lon: 7.3443202
#
#  - 2025-11-13: 5.5°C → 18.1°C
#  rainfall => 0 uv => 1 weather => Eclaircies
#  - 2025-11-14: 8.2°C → 18.2°C
#  rainfall => 0 uv => 1 weather => Ciel voilé
#
# === Forecast for Colmar, France :
# → lat: 48.0777517, lon: 7.3579641
#
#  - 2025-11-13: 6.1°C → 19°C
#  rainfall => 0 uv => 1 weather => Eclaircies
#  - 2025-11-14: 9.2°C → 21.5°C
#  rainfall => 0.3 uv => 1 weather => Ciel voilé
#
# === Forecast for Eguisheim, France :
# → lat: 48.0447968, lon: 7.3079618
#
#  - 2025-11-13: 8.4°C → 19.6°C
#  rainfall => 0 uv => 1 weather => Eclaircies
#  - 2025-11-14: 9.7°C → 20.5°C
#  rainfall => 0.3 uv => 1 weather => Ciel voilé
#
# === Forecast for Besancon, France :
# → lat: 47.2380222, lon: 6.0243622
#
#  - 2025-11-13: 6.1°C → 21.5°C
#  rainfall => 0 uv => 1 weather => Eclaircies
#  - 2025-11-14: 6.2°C → 19.1°C
#  rainfall => 1.9 uv => 1 weather => Eclaircies
#
# === Forecast for Dijon, France :
# → lat: 47.3215806, lon: 5.0414701
#
#  - 2025-11-13: 11.1°C → 20.2°C
#  rainfall => 0 uv => 1 weather => Eclaircies
#  - 2025-11-14: 12.1°C → 20.6°C
#  rainfall => 11.8 uv => 1 weather => Pluie faible
#
# === Forecast for Annecy, France :
# → lat: 45.8992348, lon: 6.1288847
#
#  - 2025-11-13: 2.1°C → 15.6°C
#  rainfall => 0 uv => 2 weather => Eclaircies
#  - 2025-11-14: 3.6°C → 15.7°C
#  rainfall => 0.4 uv => 2 weather => Eclaircies
#
# === Forecast for Grenoble, France :
# → lat: 45.1875602, lon: 5.7357819
#
#  - 2025-11-13: 9.1°C → 23.7°C
#  rainfall => 0 uv => 2 weather => Eclaircies
#  - 2025-11-14: 8.1°C → 24.5°C
#  rainfall => 0.3 uv => 2 weather => Couvert
#
# === Forecast for Lyon, France :
# → lat: 45.7578137, lon: 4.8320114
#
#  - 2025-11-13: 15.7°C → 20°C
#  rainfall => 0 uv => 2 weather => Eclaircies
#  - 2025-11-14: 15.2°C → 19.6°C
#  rainfall => 6.1 uv => 2 weather => Pluie faible
#
# === Forecast for Gorges du Verdon, France :
# → lat: 43.7496562, lon: 6.3285616
#
#  - 2025-11-13: 2.6°C → 16.1°C
#  rainfall => 0 uv => 1 weather => Eclaircies
#  - 2025-11-14: 6.9°C → 15.5°C
#  rainfall => 7.5 uv => 2 weather => Pluie faible
#
# === Forecast for Bormes les Mimosas, France :
# → lat: 43.1506968, lon: 6.3419285
#
#  - 2025-11-13: 11.9°C → 19.9°C
#  rainfall => 0 uv => 2 weather => Eclaircies
#  - 2025-11-14: 13.6°C → 20.4°C
#  rainfall => 3.4 uv => 2 weather => Pluie faible
#
# === Forecast for Cassis, France :
# → lat: 43.2140359, lon: 5.5396318
#
#  - 2025-11-13: 14.6°C → 21.5°C
#  rainfall => 0 uv => 2 weather => Eclaircies
#  - 2025-11-14: 16.2°C → 22.1°C
#  rainfall => 1.5 uv => 2 weather => Pluie faible
#
# === Forecast for Marseille, France :
# → lat: 43.2961743, lon: 5.3699525
#
#  - 2025-11-13: 14.9°C → 21.4°C
#  rainfall => 0 uv => 2 weather => Eclaircies
#  - 2025-11-14: 16.7°C → 21.1°C
#  rainfall => 0.9 uv => 2 weather => Pluie faible
#
# === Forecast for Aix en Provence, France :
# → lat: 43.5298424, lon: 5.4474738
#
#  - 2025-11-13: 9.1°C → 20.7°C
#  rainfall => 0 uv => 2 weather => Eclaircies
#  - 2025-11-14: 13.2°C → 20.1°C
#  rainfall => 1.1 uv => 2 weather => Pluie faible
#
# === Forecast for Avignon, France :
# → lat: 43.9492493, lon: 4.8059012
#
#  - 2025-11-13: 8.7°C → 21°C
#  rainfall => 0 uv => 2 weather => Eclaircies
#  - 2025-11-14: 9.1°C → 21.4°C
#  rainfall => 2.6 uv => 2 weather => Pluie faible
#
# === Forecast for Uzes, France :
# → lat: 44.0121279, lon: 4.4196718
#
#  - 2025-11-13: 10°C → 19.9°C
#  rainfall => 0 uv => 1 weather => Eclaircies
#  - 2025-11-14: 9.5°C → 20.6°C
#  rainfall => 11.1 uv => 2 weather => Pluie faible
#
# === Forecast for Nimes, France :
# → lat: 43.8374249, lon: 4.3600687
#
#  - 2025-11-13: 13.5°C → 20.6°C
#  rainfall => 0 uv => 1 weather => Eclaircies
#  - 2025-11-14: 12.1°C → 20.9°C
#  rainfall => 7.5 uv => 2 weather => Pluie faible
#
# === Forecast for Aigues Mortes, France :
# → lat: 43.5661521, lon: 4.19154
#
#  - 2025-11-13: 12.9°C → 20.5°C
#  rainfall => 0 uv => 1 weather => Couvert
#  - 2025-11-14: 16°C → 20.6°C
#  rainfall => 2.2 uv => 2 weather => Pluie faible
#
# === Forecast for Saintes Maries de la mer, France :
# → lat: 43.4515922, lon: 4.4277202
#
#  - 2025-11-13: 14°C → 19.4°C
#  rainfall => 0 uv => 1 weather => Eclaircies
#  - 2025-11-14: 16.2°C → 19.6°C
#  rainfall => 2.2 uv => 2 weather => Pluie faible
#
# === Forecast for Collioure, France :
# → lat: 42.52505, lon: 3.0831554
#
#  - 2025-11-13: 16.7°C → 20.6°C
#  rainfall => 0.2 uv => 2 weather => Eclaircies
#  - 2025-11-14: 16.4°C → 21.4°C
#  rainfall => 0.6 uv => 2 weather => Pluie faible
#
# === Forecast for Carcassonne, France :
# → lat: 43.2130358, lon: 2.3491069
#
#  - 2025-11-13: 16.5°C → 20.2°C
#  rainfall => 0 uv => 2 weather => Couvert
#  - 2025-11-14: 16.1°C → 20°C
#  rainfall => 0 uv => 2 weather => Couvert
#
# === Forecast for Ariege, France :
# → lat: 42.9455368, lon: 1.4065544
#
#  - 2025-11-13: 12.1°C → 20.5°C
#  rainfall => 0 uv => 1 weather => Eclaircies
#  - 2025-11-14: 12.6°C → 18.7°C
#  rainfall => 0.6 uv => 2 weather => Pluie faible
#
# === Forecast for Toulouse, France :
# → lat: 43.6044638, lon: 1.4442433
#
#  - 2025-11-13: 17.2°C → 21.1°C
#  rainfall => 0 uv => 2 weather => Eclaircies
#  - 2025-11-14: 16.2°C → 21.1°C
#  rainfall => 0 uv => 2 weather => Eclaircies
#
# === Forecast for Montauban, France :
# → lat: 44.0175835, lon: 1.3549991
#
#  - 2025-11-13: 16.6°C → 22.1°C
#  rainfall => 0 uv => 2 weather => Eclaircies
#  - 2025-11-14: 16.5°C → 22°C
#  rainfall => 0 uv => 2 weather => Couvert
#
# === Forecast for Biarritz, France :
# → lat: 43.4832523, lon: -1.5592776
#
#  - 2025-11-13: 21.1°C → 25.5°C
#  rainfall => 0 uv => 1 weather => Couvert
#  - 2025-11-14: 18.5°C → 23.5°C
#  rainfall => 0 uv => 2 weather => Eclaircies
#
# === Forecast for Bayonne, France :
# → lat: 43.4945144, lon: -1.4736657
#
#  - 2025-11-13: 20.7°C → 26.5°C
#  rainfall => 0.1 uv => 1 weather => Couvert
#  - 2025-11-14: 18.1°C → 24.6°C
#  rainfall => 0 uv => 2 weather => Eclaircies
#
# === Forecast for La Rochelle, France :
# → lat: 46.159732, lon: -1.1515951
#
#  - 2025-11-13: 14.1°C → 20.5°C
#  rainfall => 0 uv => 1 weather => Couvert
#  - 2025-11-14: 15.4°C → 19.1°C
#  rainfall => 1.1 uv => 1 weather => Pluie faible

# %% [markdown]
# So far so good, so let's produce now our weather forecast for one week ahead and store the information into a Pandas dataframe:

# %%
def get_forecast_by_city_fordf(city_name):
    location = geolocator.geocode(f'{city_name}, France')
    if not location:
        return city_name, None

    forecast = client.get_forecast(location.latitude, location.longitude)
    
    daily = forecast.daily_forecast[:7] #value set for the whole week
    id_place = forecast.position['insee']
    return city_name, daily, id_place, location.latitude, location.longitude

# %%
data_weather = []
for place in holiday_places:
    city, daily_forecast, id_place, lat, lon = get_forecast_by_city_fordf(place)
    if daily_forecast:
        for day in daily_forecast:
            row = {
                "insee": id_place,                
                "place": city,
                "lat": lat,
                "lon": lon,
                "date": datetime.fromtimestamp(day["dt"]).strftime("%Y-%m-%d"),
                "tmin": day["T"]["min"],
                "tmax": day["T"]["max"],
                "rainfall": day['precipitation']['24h']
            }
            data_weather.append(row)

df_weather = pd.DataFrame(data_weather)
df_weather
# Out:
#        insee              place        lat       lon        date  tmin  tmax  \
# 0    5035351  Mont Saint Michel  48.635954 -1.511460  2025-11-13  12.5  17.6
# 1    5035351  Mont Saint Michel  48.635954 -1.511460  2025-11-14  12.9  18.6
# 2    5035351  Mont Saint Michel  48.635954 -1.511460  2025-11-15  10.4  14.6
# 3    5035351  Mont Saint Michel  48.635954 -1.511460  2025-11-16  10.0  13.2
# 4    5035351  Mont Saint Michel  48.635954 -1.511460  2025-11-17   7.0  12.2
# ..       ...                ...        ...       ...         ...   ...   ...
# 240   173000        La Rochelle  46.159732 -1.151595  2025-11-15  13.4  17.6
# 241   173000        La Rochelle  46.159732 -1.151595  2025-11-16  11.2  16.9
# 242   173000        La Rochelle  46.159732 -1.151595  2025-11-17   9.2  13.6
# 243   173000        La Rochelle  46.159732 -1.151595  2025-11-18   4.9  13.2
# 244   173000        La Rochelle  46.159732 -1.151595  2025-11-19   7.4  12.5
#
#      rainfall
# 0         0.1
# 1         1.0
# 2         4.4
# 3         0.0
# 4         0.0
# ..        ...
# 240       1.2
# 241       0.0
# 242       0.0
# 243       0.0
# 244       6.4
#
# [245 rows x 8 columns]

# %%
pd.DataFrame.to_csv(df_weather, "data/weekly_weather_forecast.csv", index=False)

# %% [markdown]
# We now have weekly forecasts! The previous cell allowed us to store it into a csv file for later retrieval - it also serves as a checkpoint for the next steps.
#
# ### Selecting weather data
#
# We will now work on our forecasts to enable the display of the average temperature on a given day, the expected rainfall, then the weekly average temperature:

# %%
df_weather = pd.read_csv("data/weekly_weather_forecast.csv")
df_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   insee     245 non-null    int64
#  1   place     245 non-null    object
#  2   lat       245 non-null    float64
#  3   lon       245 non-null    float64
#  4   date      245 non-null    object
#  5   tmin      245 non-null    float64
#  6   tmax      245 non-null    float64
#  7   rainfall  245 non-null    float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 15.4+ KB

# %%
df_weather.head()
# Out:
#      insee              place        lat      lon        date  tmin  tmax  \
# 0  5035351  Mont Saint Michel  48.635954 -1.51146  2025-11-13  12.5  17.6
# 1  5035351  Mont Saint Michel  48.635954 -1.51146  2025-11-14  12.9  18.6
# 2  5035351  Mont Saint Michel  48.635954 -1.51146  2025-11-15  10.4  14.6
# 3  5035351  Mont Saint Michel  48.635954 -1.51146  2025-11-16  10.0  13.2
# 4  5035351  Mont Saint Michel  48.635954 -1.51146  2025-11-17   7.0  12.2
#
#    rainfall
# 0       0.1
# 1       1.0
# 2       4.4
# 3       0.0
# 4       0.0

# %%
df_weather['td_mean'] = np.mean(df_weather[['tmin', 'tmax']], axis=1) #daily average temperature
df_weather
# Out:
#        insee              place        lat       lon        date  tmin  tmax  \
# 0    5035351  Mont Saint Michel  48.635954 -1.511460  2025-11-13  12.5  17.6
# 1    5035351  Mont Saint Michel  48.635954 -1.511460  2025-11-14  12.9  18.6
# 2    5035351  Mont Saint Michel  48.635954 -1.511460  2025-11-15  10.4  14.6
# 3    5035351  Mont Saint Michel  48.635954 -1.511460  2025-11-16  10.0  13.2
# 4    5035351  Mont Saint Michel  48.635954 -1.511460  2025-11-17   7.0  12.2
# ..       ...                ...        ...       ...         ...   ...   ...
# 240   173000        La Rochelle  46.159732 -1.151595  2025-11-15  13.4  17.6
# 241   173000        La Rochelle  46.159732 -1.151595  2025-11-16  11.2  16.9
# 242   173000        La Rochelle  46.159732 -1.151595  2025-11-17   9.2  13.6
# 243   173000        La Rochelle  46.159732 -1.151595  2025-11-18   4.9  13.2
# 244   173000        La Rochelle  46.159732 -1.151595  2025-11-19   7.4  12.5
#
#      rainfall  td_mean
# 0         0.1    15.05
# 1         1.0    15.75
# 2         4.4    12.50
# 3         0.0    11.60
# 4         0.0     9.60
# ..        ...      ...
# 240       1.2    15.50
# 241       0.0    14.05
# 242       0.0    11.40
# 243       0.0     9.05
# 244       6.4     9.95
#
# [245 rows x 9 columns]

# %%
df_w = df_weather.copy(deep=True)
df_w['rainw_mean'] = df_w.groupby('insee')['rainfall'].transform("mean") #weekly average rainfall
df_w['tw_mean'] = df_w.groupby('insee')['td_mean'].transform("mean") #weekly average temperature
df_w.head(10)
# Out:
#      insee              place        lat       lon        date  tmin  tmax  \
# 0  5035351  Mont Saint Michel  48.635954 -1.511460  2025-11-13  12.5  17.6
# 1  5035351  Mont Saint Michel  48.635954 -1.511460  2025-11-14  12.9  18.6
# 2  5035351  Mont Saint Michel  48.635954 -1.511460  2025-11-15  10.4  14.6
# 3  5035351  Mont Saint Michel  48.635954 -1.511460  2025-11-16  10.0  13.2
# 4  5035351  Mont Saint Michel  48.635954 -1.511460  2025-11-17   7.0  12.2
# 5  5035351  Mont Saint Michel  48.635954 -1.511460  2025-11-18   3.9  10.4
# 6  5035351  Mont Saint Michel  48.635954 -1.511460  2025-11-19   5.4   9.1
# 7  3528885            St Malo  48.649518 -2.026041  2025-11-13  12.9  18.1
# 8  3528885            St Malo  48.649518 -2.026041  2025-11-14  13.7  19.1
# 9  3528885            St Malo  48.649518 -2.026041  2025-11-15  10.5  16.2
#
#    rainfall  td_mean  rainw_mean    tw_mean
# 0       0.1    15.05    2.671429  11.271429
# 1       1.0    15.75    2.671429  11.271429
# 2       4.4    12.50    2.671429  11.271429
# 3       0.0    11.60    2.671429  11.271429
# 4       0.0     9.60    2.671429  11.271429
# 5       3.0     7.15    2.671429  11.271429
# 6      10.2     7.25    2.671429  11.271429
# 7       0.7    15.50    2.900000  12.314286
# 8       1.4    16.40    2.900000  12.314286
# 9       2.6    13.35    2.900000  12.314286

# %% [markdown]
# With our daily & weekly averages now available, let's bring it all back to a single row per location:

# %%
df_w1 = df_w.groupby(by='insee').last().reset_index()
df_w1.head()
# Out:
#     insee             place        lat       lon        date  tmin  tmax  \
# 0   41440  Gorges du Verdon  43.749656  6.328562  2025-11-19  -1.9  11.1
# 1   91960            Ariege  42.945537  1.406554  2025-11-19   2.6   9.0
# 2  110690       Carcassonne  43.213036  2.349107  2025-11-19   4.6  12.7
# 3  130010   Aix en Provence  43.529842  5.447474  2025-11-19   5.6  13.1
# 4  130220            Cassis  43.214036  5.539632  2025-11-19   9.2  15.4
#
#    rainfall  td_mean  rainw_mean    tw_mean
# 0       0.2     4.60    6.357143   8.378571
# 1       0.6     5.80    1.571429  10.828571
# 2       0.0     8.65    0.028571  14.371429
# 3       0.0     9.35    6.528571  13.850000
# 4       0.0    12.30    8.857143  16.121429

# %% [markdown]
# Then we will keep the key informations to determine what we consider a "nice weather" for holidays. For simplicity, we'll keep weekly rainfall & temperatures:

# %%
df_w2 = df_w1.drop(columns=['tmin', 'tmax', 'rainfall', 'td_mean'])
df_w2.head()
# Out:
#     insee             place        lat       lon        date  rainw_mean  \
# 0   41440  Gorges du Verdon  43.749656  6.328562  2025-11-19    6.357143
# 1   91960            Ariege  42.945537  1.406554  2025-11-19    1.571429
# 2  110690       Carcassonne  43.213036  2.349107  2025-11-19    0.028571
# 3  130010   Aix en Provence  43.529842  5.447474  2025-11-19    6.528571
# 4  130220            Cassis  43.214036  5.539632  2025-11-19    8.857143
#
#      tw_mean
# 0   8.378571
# 1  10.828571
# 2  14.371429
# 3  13.850000
# 4  16.121429

# %% [markdown]
# Then we will begin by determining a "nice weather" as one with little rainfalls:

# %%
df_w3 = df_w2[df_w2['rainw_mean'] <= 3 ]
df_w3.head(20)
# Out:
#       insee                         place        lat       lon        date  \
# 1     91960                        Ariege  42.945537  1.406554  2025-11-19
# 2    110690                   Carcassonne  43.213036  2.349107  2025-11-19
# 6    140470                        Bayeux  49.276462 -0.702474  2025-11-19
# 7    173000                   La Rochelle  46.159732 -1.151595  2025-11-19
# 13   315550                      Toulouse  43.604464  1.444243  2025-11-19
# 15   593500                         Lille  50.636565  3.063528  2025-11-19
# 17   660530                     Collioure  42.525050  3.083155  2025-11-19
# 18   674820                    Strasbourg  48.584614  7.750713  2025-11-19
# 19   680660                        Colmar  48.077752  7.357964  2025-11-19
# 20   680780                     Eguisheim  48.044797  7.307962  2025-11-19
# 21   682800  Chateau du Haut Koenigsbourg  48.249411  7.344320  2025-11-19
# 24   751050                         Paris  48.853495  2.348391  2025-11-19
# 26   765400                         Rouen  49.440459  1.093966  2025-11-19
# 27   800210                        Amiens  49.894171  2.295695  2025-11-19
# 28   821210                     Montauban  44.017584  1.354999  2025-11-19
# 31  1309651      Saintes Maries de la mer  43.451592  4.427720  2025-11-19
# 32  3528885                       St Malo  48.649518 -2.026041  2025-11-19
# 33  5035351             Mont Saint Michel  48.635954 -1.511460  2025-11-19
#
#     rainw_mean    tw_mean
# 1     1.571429  10.828571
# 2     0.028571  14.371429
# 6     1.871429  11.178571
# 7     1.257143  13.521429
# 13    0.157143  13.992857
# 15    0.785714   9.600000
# 17    0.271429  16.178571
# 18    1.914286   8.942857
# 19    2.357143   9.107143
# 20    2.342857   9.000000
# 21    1.885714   8.235714
# 24    0.914286  10.657143
# 26    1.814286  10.342857
# 27    1.057143   9.642857
# 28    0.200000  13.628571
# 31    2.371429  15.335714
# 32    2.900000  12.314286
# 33    2.671429  11.271429

# %% [markdown]
# Next, we will keep the highest temperatures available given the season - for the sake of summer, it would take a little more work to remain below 35°C:

# %%
df_w4 = df_w3.sort_values(by='tw_mean', ascending=False)

# %% [markdown]
# And finally, we can extract our top 5 locations!

# %%
df_w5 = df_w4.head(5)
df_w5
# Out:
#       insee                     place        lat       lon        date  \
# 17   660530                 Collioure  42.525050  3.083155  2025-11-19
# 31  1309651  Saintes Maries de la mer  43.451592  4.427720  2025-11-19
# 2    110690               Carcassonne  43.213036  2.349107  2025-11-19
# 13   315550                  Toulouse  43.604464  1.444243  2025-11-19
# 28   821210                 Montauban  44.017584  1.354999  2025-11-19
#
#     rainw_mean    tw_mean
# 17    0.271429  16.178571
# 31    2.371429  15.335714
# 2     0.028571  14.371429
# 13    0.157143  13.992857
# 28    0.200000  13.628571

# %% [markdown]
# # Top5 locations: first visualization
#
# Now that we have a top 5 for our locations with the best weather available, let's have them displayed on a map to get an idea of the end result we expect!

# %%
fig5 = px.scatter_map(df_w5, lat="lat", lon="lon", color="tw_mean", hover_name="place", 
                     hover_data=["rainw_mean", "tw_mean"], size="tw_mean", zoom=4)
fig5.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig5.show()

# %% [markdown]
# # Scrapping hotels' informations
#
# Our weather data per location is ready, we can deal with the hotels now. Follow the next steps to begin the scrapping part:

# %% [markdown]
# ### Getting 20 hotels' urls per location
#
# 1. Be sure you followed our [earlier instructions](#basic-information) in setting up your environment, and running this notebook with the new M174_kayak.
# 2. Run our first spider: `python src/booking_url_hotel.py`
#     * Should it fail to execute, check again what path is displayed before your commands - it **must** be the cdsd_kayak folder to work as intended.
# 3. Keep your Anaconda prompt open until the spider is done (see below) - we will execute another one in the same context right after!
#     * Feel free to check the json output under `data/all_cities_url.json` to ensure all 700 rows are available without any missing values.

# %% [markdown]
# ### Recovering each hotel's data
#
# 1. Make sure the previous spider's work successfully finished; its last message should end with `INFO: Spider closed (finished)`.
#     * In any other case, you will likely have to repeat the previous spider's steps - especially making sure you're executing commands in the right working directory.
#     * While working on the project, data traffic seems to hamper our data recovery. You may have to rerun the spider.
# 2. Since you should still be under said working directory, run our second spider with `python src/booking_info_hotel.py`
# 3. Give it again time to complete its work (~45 minutes), this one will take longer and wait for the `INFO: Spider closed (finished)` message!
#     * Feel free again to check the json output under `data/hotels_details.json` to make sure at least all informations were recovered on at least one hotel.
#     * This part is the most likely to fail with data traffic, keep trying! `ctrl+C` in your terminal will interrupt the spider if you can tell it is failing.

# %% [markdown]
# ### Merging our informations
#
# With our data now extracted, we can now push further by merging it all into a cohesive json file!

# %%
df_w2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   insee       35 non-null     int64
#  1   place       35 non-null     object
#  2   lat         35 non-null     float64
#  3   lon         35 non-null     float64
#  4   date        35 non-null     object
#  5   rainw_mean  35 non-null     float64
#  6   tw_mean     35 non-null     float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 2.0+ KB

# %%
df_w2.head()
# Out:
#     insee             place        lat       lon        date  rainw_mean  \
# 0   41440  Gorges du Verdon  43.749656  6.328562  2025-11-19    6.357143
# 1   91960            Ariege  42.945537  1.406554  2025-11-19    1.571429
# 2  110690       Carcassonne  43.213036  2.349107  2025-11-19    0.028571
# 3  130010   Aix en Provence  43.529842  5.447474  2025-11-19    6.528571
# 4  130220            Cassis  43.214036  5.539632  2025-11-19    8.857143
#
#      tw_mean
# 0   8.378571
# 1  10.828571
# 2  14.371429
# 3  13.850000
# 4  16.121429

# %%
with open("data/hotels_details.json", "r", encoding="utf-8") as f:
    hotels = json.load(f)

df_hotels = pd.DataFrame(hotels)
df_merged = pd.merge(df_hotels, df_w2, on='place', how="right")
hotels_enriched = df_merged.to_dict(orient="records") #associating columns & data as keys & values for JSON dumping

with open("data/all_hotels_details_insee.json", "w", encoding="utf-8") as f:
    json.dump(hotels_enriched, f, indent=4, ensure_ascii=False) #save as JSON for later use

# %% [markdown]
# # Finalizing the transformations of our data
#
# Now that data collection is done, let's give it its final shape! First on the list is cleaning our dataset for ease of use:

# %%
with open("data/all_hotels_details_insee.json", "r", encoding="utf-8") as f:
    all_hotels_details = json.load(f)
df = pd.DataFrame(all_hotels_details)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   place        700 non-null    object
#  1   url          700 non-null    object
#  2   name         700 non-null    object
#  3   note         700 non-null    object
#  4   address      700 non-null    object
#  5   description  700 non-null    object
#  6   insee        700 non-null    int64
#  7   lat          700 non-null    float64
#  8   lon          700 non-null    float64
#  9   date         700 non-null    object
#  10  rainw_mean   700 non-null    float64
#  11  tw_mean      700 non-null    float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 65.8+ KB

# %%
df.head(1)
# Out:
#               place                                                url  \
# 0  Gorges du Verdon  https://www.booking.com/hotel/fr/studio-arc-en...
#
#             name                  note  \
# 0  L'Arc en Ciel  Avec une note de 9.1
#
#                                              address  \
# 0  80 Chemin du Plan, 04800 Gréoux-les-Bains, France
#
#                                          description  insee        lat  \
# 0  L’établissement L'Arc en Ciel se situe à 17 km...  41440  43.749656
#
#         lon        date  rainw_mean   tw_mean
# 0  6.328562  2025-11-19    6.357143  8.378571

# %% [markdown]
# We'd like a convenient note format, so a little work on it is required:

# %%
df['note'] = df['note'].str.split('de ').str[-1]
df['note'] = pd.to_numeric(df['note'], errors="coerce")
df.head(1)
# Out:
#               place                                                url  \
# 0  Gorges du Verdon  https://www.booking.com/hotel/fr/studio-arc-en...
#
#             name  note                                            address  \
# 0  L'Arc en Ciel   9.1  80 Chemin du Plan, 04800 Gréoux-les-Bains, France
#
#                                          description  insee        lat  \
# 0  L’établissement L'Arc en Ciel se situe à 17 km...  41440  43.749656
#
#         lon        date  rainw_mean   tw_mean
# 0  6.328562  2025-11-19    6.357143  8.378571

# %% [markdown]
# Now we will want to recover GPS coordinates for each precise address, rather than per city/area. We've chosen HERE for this purpose for its free tier:

# %%
def geocode_here(address):
    r = requests.get(f"{HERE_api_url}geocode?q={address}&apikey={HERE_api_key}").json()
    #html response is in binary format; to json for ease of items' retrieval
    if "items" in r and len(r["items"]) > 0:
        lat_h = r["items"][0]["position"]["lat"]
        lon_h = r["items"][0]["position"]["lng"]
        return lat_h, lon_h
    else:
        return None, None #exception management

# %%
# Uncomment the line below to extract precise GPS coordinates; remember to put it back as a comment afterwards to avoid requesting your HERE API key too often, possibly incurring fees after a while!
#df[["lat_h", "lon_h"]] = df["address"].apply(lambda x: pd.Series(geocode_here(x)))
df.head(1)
# Out:
#               place                                                url  \
# 0  Gorges du Verdon  https://www.booking.com/hotel/fr/studio-arc-en...
#
#             name  note                                            address  \
# 0  L'Arc en Ciel   9.1  80 Chemin du Plan, 04800 Gréoux-les-Bains, France
#
#                                          description  insee        lat  \
# 0  L’établissement L'Arc en Ciel se situe à 17 km...  41440  43.749656
#
#         lon        date  rainw_mean   tw_mean     lat_h    lon_h
# 0  6.328562  2025-11-19    6.357143  8.378571  43.75664  5.87664

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   place        700 non-null    object
#  1   url          700 non-null    object
#  2   name         700 non-null    object
#  3   note         700 non-null    float64
#  4   address      700 non-null    object
#  5   description  700 non-null    object
#  6   insee        700 non-null    int64
#  7   lat          700 non-null    float64
#  8   lon          700 non-null    float64
#  9   date         700 non-null    object
#  10  rainw_mean   700 non-null    float64
#  11  tw_mean      700 non-null    float64
#  12  lat_h        700 non-null    float64
#  13  lon_h        700 non-null    float64
# dtypes: float64(7), int64(1), object(6)
# memory usage: 76.7+ KB

# %% [markdown]
# # Top20 hotels per location
#
# We finally have the proper state for our dataframe to reach our goals! Even if we expect some cluttering, how about a preview of the final result?

# %% [markdown]
# ### Best hotels by user notes

# %%
fig20n = px.scatter_map(df, lat="lat_h", lon="lon_h", color="note", color_continuous_scale="Turbo",
                     hover_name="name", hover_data=["url", "address"], zoom=4)
fig20n.update_traces(marker_size=10)
fig20n.update_layout(map_style="basic", margin={"r":0,"t":0,"l":0,"b":0})
fig20n.show()

# %% [markdown]
# ### Best hotels by expected temperature

# %%
fig20t = px.scatter_map(df, lat="lat", lon="lon", color="tw_mean", color_continuous_scale="Turbo",
                     hover_name="name", hover_data=["url", "address"], zoom=4)
fig20t.update_traces(marker_size=10)
fig20t.update_layout(map_style="basic", margin={"r":0,"t":0,"l":0,"b":0})
fig20t.show()

# %%
pd.DataFrame.to_csv(df, "data/hotels_info.csv", index=False)

# %% [markdown]
# # Building our online infrastructure
#
# Since we will be referring to environment variables defined at the very beginning, you may want to jump back there with [this link](#environment-variables-setup) for a reminder!

# %% [markdown]
# ### Pushing our final dataframe to S3

# %%
session = boto3.Session(aws_access_key_id=AWS_id, aws_secret_access_key=AWS_secret_key)
s3 = boto3.client('s3')

# %%
# Uncomment the next line to actually push the file; don't forget to comment it back to avoid multiple pushes that may be billed by AWS!
#s3.upload_file("data/hotels_info.csv", S3_bucket, "kayak_project/hotels_info.csv")

# %% [markdown]
# ### Connecting to our distant SQL

# %%
engine = create_engine(neonDB, echo=True)

# %%
# Uncomment the following lines to retrieve our newly created S3 file before pushing it to the SQL database; once more to avoid billing (by NeonDB), be sure to comment it back after the push!
#df_transit = pd.read_csv(f"{S3_uri}hotels_info.csv")
#df_transit.to_sql("kayak_project", engine, if_exists="replace", index=True)
# Out:
# 2025-11-18 20:25:42,543 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2025-11-18 20:25:42,544 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-11-18 20:25:42,599 INFO sqlalchemy.engine.Engine select current_schema()
# 2025-11-18 20:25:42,599 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-11-18 20:25:42,653 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2025-11-18 20:25:42,654 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-11-18 20:25:42,707 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-18 20:25:42,714 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-11-18 20:25:42,715 INFO sqlalchemy.engine.Engine [generated in 0.00072s] {'table_name': 'kayak_project', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-11-18 20:25:42,783 INFO sqlalchemy.engine.Engine
# CREATE TABLE kayak_project (
# 	index BIGINT,
# 	place TEXT,
# 	url TEXT,
# 	name TEXT,
# 	note FLOAT(53),
# 	address TEXT,
# 	description TEXT,
# 	insee BIGINT,
# 	lat FLOAT(53),
# 	lon FLOAT(53),
# 	date TEXT,
# 	rainw_mean FLOAT(53),
# 	tw_mean FLOAT(53),
# 	lat_h FLOAT(53),
# 	lon_h FLOAT(53)
# )
#
#
# 2025-11-18 20:25:42,784 INFO sqlalchemy.engine.Engine [no key 0.00080s] {}
# 2025-11-18 20:25:42,849 INFO sqlalchemy.engine.Engine CREATE INDEX ix_kayak_project_index ON kayak_project (index)
# 2025-11-18 20:25:42,849 INFO sqlalchemy.engine.Engine [no key 0.00082s] {}
# 2025-11-18 20:25:42,889 INFO sqlalchemy.engine.Engine INSERT INTO kayak_project (index, place, url, name, note, address, description, insee, lat, lon, date, rainw_mean, tw_mean, lat_h, lon_h) VALUES (%(index__0)s, %(place__0)s, %(url__0)s, %(name__0)s, %(note__0)s, %(address__0)s, %(description__0)s, %( ... 171743 characters truncated ...  %(lon__699)s, %(date__699)s, %(rainw_mean__699)s, %(tw_mean__699)s, %(lat_h__699)s, %(lon_h__699)s)
# 2025-11-18 20:25:42,890 INFO sqlalchemy.engine.Engine [generated in 0.00313s (insertmanyvalues) 1/1 (unordered)] {'rainw_mean__0': 6.357142857142857, 'lon__0': 6.3285616, 'lat_h__0': 43.75664, 'index__0': 0, 'place__0': 'Gorges du Verdon', 'date__0': '2025-11-19', 'name__0': "L'Arc en Ciel", 'description__0': "L’établissement L'Arc en Ciel se situe à 17 km de ce lieu d’intérêt : Agence ITER de Cadarache. Il possède une connexion Wi-Fi gratuite et un parking ... (486 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 'note__0': 9.1, 'lat__0': 43.7496562, 'url__0': 'https://www.booking.com/hotel/fr/studio-arc-en-ciel.fr.html', 'lon_h__0': 5.87664, 'address__0': '80 Chemin du Plan, 04800 Gréoux-les-Bains, France', 'tw_mean__0': 8.378571428571428, 'insee__0': 41440, 'rainw_mean__1': 6.357142857142857, 'lon__1': 6.3285616, 'lat_h__1': 43.77535, 'index__1': 1, 'place__1': 'Gorges du Verdon', 'date__1': '2025-11-19', 'name__1': 'Le Vieux Château', 'description__1': "Occupant un bâtiment du XVIIIe siècle, Le Vieux Château propose des chambres avec connexion Wi-Fi gratuite, un bar et une terrasse. Situé dans le cen ... (797 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 'note__1': 7.5, 'lat__1': 43.7496562, 'url__1': 'https://www.booking.com/hotel/fr/du-vieux-chateau.fr.html', 'lon_h__1': 6.24325, 'address__1': 'Place de la Fontaine, 83630 Aiguines, France', 'tw_mean__1': 8.378571428571428, 'insee__1': 41440, 'rainw_mean__2': 6.357142857142857, 'lon__2': 6.3285616, 'lat_h__2': 43.75627, 'index__2': 2, 'place__2': 'Gorges du Verdon', 'date__2': '2025-11-19', 'name__2': 'Résidence Lou Cigaloun - ANA LOCATION', 'description__2': "L’établissement Résidence Lou Cigaloun - ANA LOCATION vous accueille à Gréoux-les-Bains (Provence-Alpes-Côte d'Azur), à 18 km de ce lieu d’intérêt :  ... (851 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 'note__2': 9.2, 'lat__2': 43.7496562, 'url__2': 'https://www.booking.com/hotel/fr/residence-lou-cigaloun-greoux-les-bains.fr.html', 'lon_h__2': 5.88049, 'address__2': '623 Avenue Jean Moulin, 04800 Gréoux-les-Bains, France', 'tw_mean__2': 8.378571428571428, 'insee__2': 41440, 'rainw_mean__3': 6.357142857142857, 'lon__3': 6.3285616, 'lat_h__3': 43.76921, 'index__3': 3, 'place__3': 'Gorges du Verdon' ... 10400 parameters truncated ... 'url__696': 'https://www.booking.com/hotel/fr/inter-windsor.fr.html', 'lon_h__696': -1.55849, 'address__696': '11 Avenue Edouard VII, 64200 Biarritz, France', 'tw_mean__696': 15.35, 'insee__696': 6402481, 'rainw_mean__697': 3.5142857142857147, 'lon__697': -1.5527266, 'lat_h__697': 43.49063, 'index__697': 697, 'place__697': 'Biarritz', 'date__697': '2025-11-19', 'name__697': 'Le Garage Biarritz Hôtel', 'description__697': "Situé en bord de mer, l’établissement Le Garage Biarritz Hôtel propose des hébergements 4 étoiles à Biarritz. Il possède une piscine extérieure ouver ... (1031 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 'note__697': 9.1, 'lat__697': 43.4711438, 'url__697': 'https://www.booking.com/hotel/fr/le-garage-regina.fr.html', 'lon_h__697': -1.55208, 'address__697': "50 Avenue de l'Impératrice, 64200 Biarritz, France", 'tw_mean__697': 15.35, 'insee__697': 6402481, 'rainw_mean__698': 3.5142857142857147, 'lon__698': -1.5527266, 'lat_h__698': 43.48225, 'index__698': 698, 'place__698': 'Biarritz', 'date__698': '2025-11-19', 'name__698': 'Hôtel Florida', 'description__698': "Situé en bord de mer à Biarritz, l’Hôtel Florida vous accueille à seulement 300 mètres de la  ...
# 2025-11-18 20:25:43,124 INFO sqlalchemy.engine.Engine COMMIT
# 700

# %% [markdown]
# Then a little preview to make sure everything works as intended?

# %%
test_statement = text("SELECT * FROM kayak_project ORDER BY index")
test_conn = engine.connect()
test_result = test_conn.execute(test_statement)
test_result.fetchall()
# Out:
# 2025-11-18 23:14:09,487 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2025-11-18 23:14:09,488 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-11-18 23:14:09,540 INFO sqlalchemy.engine.Engine select current_schema()
# 2025-11-18 23:14:09,541 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-11-18 23:14:09,594 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2025-11-18 23:14:09,594 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-11-18 23:14:09,647 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-18 23:14:09,649 INFO sqlalchemy.engine.Engine SELECT * FROM kayak_project ORDER BY index
# 2025-11-18 23:14:09,650 INFO sqlalchemy.engine.Engine [generated in 0.00249s] {}
# [(0, 'Gorges du Verdon', 'https://www.booking.com/hotel/fr/studio-arc-en-ciel.fr.html', "L'Arc en Ciel", 9.1, '80 Chemin du Plan, 04800 Gréoux-les-Bains, France', "L’établissement L'Arc en Ciel se situe à 17 km de ce lieu d’intérêt : Agence ITER de Cadarache. Il possède une connexion Wi-Fi gratuite et un parking ... (486 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 41440, 43.7496562, 6.3285616, '2025-11-19', 6.357142857142857, 8.378571428571428, 43.75664, 5.87664),
#  (1, 'Gorges du Verdon', 'https://www.booking.com/hotel/fr/du-vieux-chateau.fr.html', 'Le Vieux Château', 7.5, 'Place de la Fontaine, 83630 Aiguines, France', "Occupant un bâtiment du XVIIIe siècle, Le Vieux Château propose des chambres avec connexion Wi-Fi gratuite, un bar et une terrasse. Situé dans le cen ... (797 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 41440, 43.7496562, 6.3285616, '2025-11-19', 6.357142857142857, 8.378571428571428, 43.77535, 6.24325),
#  (2, 'Gorges du Verdon', 'https://www.booking.com/hotel/fr/residence-lou-cigaloun-greoux-les-bains.fr.html', 'Résidence Lou Cigaloun - ANA LOCATION', 9.2, '623 Avenue Jean Moulin, 04800 Gréoux-les-Bains, France', "L’établissement Résidence Lou Cigaloun - ANA LOCATION vous accueille à Gréoux-les-Bains (Provence-Alpes-Côte d'Azur), à 18 km de ce lieu d’intérêt :  ... (851 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 41440, 43.7496562, 6.3285616, '2025-11-19', 6.357142857142857, 8.378571428571428, 43.75627, 5.88049),
#  (3, 'Gorges du Verdon', 'https://www.booking.com/hotel/fr/l-39-establoun.fr.html', "L'Establoun", 9.5, 'Chemin de la Palud - D82, 04800 Saint-Martin-de-Brômes, France', "L’hébergement L'Establoun se trouve à Saint-Martin-de-Brômes, à respectivement 24 km et 28 km de ces lieux d’intérêt : Agence ITER de Cadarache et Go ... (771 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 41440, 43.7496562, 6.3285616, '2025-11-19', 6.357142857142857, 8.378571428571428, 43.76921, 5.94973),
#  (4, 'Gorges du Verdon', 'https://www.booking.com/hotel/fr/hotellouparadou.fr.html', 'Hôtel & Résidence Lou Paradou Gréoux Les Bains', 8.8, 'Route de Valensole, 04800 Gréoux-les-Bains, France', "L'hôtel Hôtel & Résidence Lou Paradou Gréoux Les Bains vous accueille à Gréoux-les-Bains, au bord du Verdon, au milieu des champs de lavande du cœur  ... (1128 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 41440, 43.7496562, 6.3285616, '2025-11-19', 6.357142857142857, 8.378571428571428, 43.76035, 5.88891),
#  (5, 'Gorges du Verdon', 'https://www.booking.com/hotel/fr/les-framboiseilles.fr.html', 'Camping White Rock', 8.9, 'La Lagne, 04120 Castellane, France', "L’établissement Camping White Rock se situe à Castellane (Provence-Alpes-Côte d'Azur), à 17 km de ce lieu d’intérêt : Golf du Château de Taulane. Il  ... (611 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 41440, 43.7496562, 6.3285616, '2025-11-19', 6.357142857142857, 8.378571428571428, 43.84373, 6.5431),
#  (6, 'Gorges du Verdon', 'https://www.booking.com/hotel/fr/auberge-du-bourguet.fr.html', 'Auberge du Bourguet', 8.7, 'Impasse du chateau, 83840 Brenon, France', "L’établissement Auberge du Bourguet se trouve à Brenon, à 20 km de ce lieu d’intérêt : Golf du Château de Taulane. Il propose de nombreuses installat ... (497 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 41440, 43.7496562, 6.3285616, '2025-11-19', 6.357142857142857, 8.378571428571428, 43.78327, 6.51861),
#  (7, 'Gorges du Verdon', 'https://www.booking.com/hotel/fr/holiday-home-la-clorinde.fr.html', 'La Clorinde', 9.1, 'chemin du Jas du colombier, 04360 Moustiers-Sainte-Marie, France', "Située au cœur d'une oliveraie, à 800 mètres du village de Moustiers, La Clorinde est idéalement située pour découvrir les Gorges du Verdon (1.5Km) e ... (776 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 41440, 43.7496562, 6.3285616, '2025-11-19', 6.357142857142857, 8.378571428571428, 43.83864, 6.21733),
#  (8, 'Gorges du Verdon', 'https://www.booking.com/hotel/fr/chaux-et-cristal.fr.html', 'CASA ANANTA Appartements bien-être aux portes du Verdon Refuge slow Life et sensoriel jusqu à 12 pers', 9.2, '67 Rue de la Fontaine, 04120 La Garde, France', "L’établissement CASA ANANTA Appartements bien-être aux portes du Verdon Refuge slow Life et sensoriel jusqu à 12 pers se situe à La Garde, à 14 km de ... (676 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 41440, 43.7496562, 6.3285616, '2025-11-19', 6.357142857142857, 8.378571428571428, 43.81563, 6.64449),
#  (9, 'Gorges du Verdon', 'https://www.booking.com/hotel/fr/camping-la-ferme-de-castellane.fr.html', 'Camping La Ferme de Castellane', 9.1, '1451 Chemin de Destourbes, 04120 Castellane, France', "Situé dans le village de Castellane, le Camping La Ferme de Castellane est niché sur les berges de la rivière, à moins de 5\xa0minutes de route des g ... (1442 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 41440, 43.7496562, 6.3285616, '2025-11-19', 6.357142857142857, 8.378571428571428, 43.84596, 6.51291),
#  (10, 'Gorges du Verdon', 'https://www.booking.com/hotel/fr/auberge-de-baudinard.fr.html', 'Auberge de Baudinard sur Verdon', 8.7, '37 Grand rue, 83630 Baudinard, France', "L’établissement Auberge de Baudinard sur Verdon vous accueille à Baudinard, à 44 km de ce lieu d’intérêt : Agence ITER de Cadarache. Il comprend une  ... (572 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 41440, 43.7496562, 6.3285616, '2025-11-19', 6.357142857142857, 8.378571428571428, 43.71593, 6.13405),
#  (11, 'Gorges du Verdon', 'https://www.booking.com/hotel/fr/b29-magnifique-studio-tres-bien-place-wifi-tv.fr.html', 'Superbes studios du Parc Paradis', 8.7, '469 Avenue des Thermes, 04800 Gréoux-les-Bains, France', "Offrant une vue sur le jardin, l’établissement Superbes studios du Parc Paradis comprend une connexion Wi-Fi gratuite et un parking privé gratuit. Il ... (574 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 41440, 43.7496562, 6.3285616, '2025-11-19', 6.357142857142857, 8.378571428571428, 43.75801, 5.89409),
#  (12, 'Gorges du Verdon', 'https://www.booking.com/hotel/fr/la-licorne-de-haute-provence.fr.html', 'Résidence Odalys La Licorne de Haute Provence', 7.3, 'Les Riayes, 04800 Gréoux-les-Bains, France', "Située à 500 mètres du village et à 800 mètres des thermes, la Résidence Odalys La Licorne de Haute Provence se compose de 3 petits complexes. Elle c ... (680 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 41440, 43.7496562, 6.3285616, '2025-11-19', 6.357142857142857, 8.378571428571428, 43.76161, 5.88776),
#  (13, 'Gorges du Verdon', 'https://www.booking.com/hotel/fr/angouire-gite-quot-la-bergerie-quot.fr.html', 'Mymoustiers', 8.1, "Domaine d'Angouire, 04360 Moustiers-Sainte-Marie, France", "La Mymoustiers vous propose des maisons de vacances situées dans la commune de Moustiers-Sainte-Marie, au cœur d'un parc privé de 15 hectares. Le lac ... (968 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 41440, 43.7496562, 6.3285616, '2025-11-19', 6.357142857142857, 8.378571428571428, 43.82922, 6.22821),
#  (14, 'Gorges du Verdon', 'https://www.booking.com/hotel/fr/auberge-verdon.fr.html', 'B&B Auberge Verdon', 8.5, 'Auberge Verdon La Valdenay, 04120 La Palud-sur-Verdon, France', "Dotée d'une terrasse bien exposée et offrant une vue sur la montagne, la chambre d'hôtes B&B Auberge Verdon est située à La Palud dans la région Prov ... (565 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 41440, 43.7496562, 6.3285616, '2025-11-19', 6.357142857142857, 8.378571428571428, 43.77704, 6.361),
#  (15, 'Gorges du Verdon', 'https://www.booking.com/hotel/fr/gite-t2-independant.fr.html', 'La casa Elisa Gîte T2 indépendant', 9.7, 'Chemin du Hameau du Plan,13 Lotissement les Hautes Rives du Verdon, 04800 Gréoux-les-Bains, France', "Situé à Gréoux-les-Bains, l’hébergement La casa Elisa Gîte T2 indépendant offre une vue sur le jardin. Il possède une terrasse et une connexion Wi-Fi ... (644 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 41440, 43.7496562, 6.3285616, '2025-11-19', 6.357142857142857, 8.378571428571428, 43.75208, 5.87522),
#  (16, 'Gorges du Verdon', 'https://www.booking.com/hotel/fr/le-colombier-moustiers-sainte-marie.fr.html', 'Hôtel Le Colombier', 9.4, '166 Route de La Palud, 04360 Moustiers-Sainte-Marie, France', "Installé à 1 km du cœur du village de Moustiers-Sainte-Marie, l’Hôtel Le Colombier n’est qu’à 5 km du lac de Sainte-Croix. Cette maison provençale di ... (665 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 41440, 43.7496562, 6.3285616, '2025-11-19', 6.357142857142857, 8.378571428571428, 43.84009, 6.22239),
#  (17, 'Gorges du Verdon', 'https://www.booking.com/hotel/fr/le-gite-du-grand-cedre.fr.html', 'Le gite du grand cèdre - proche des gorges du Verdon', 9.4, '45 chemin de Roumpe Cuou, 04500 Allemagne-en-Provence, France', "L’hébergement Le gite du grand cèdre - proche des gorges du Verdon vous accueille à Allemagne-en-Provence, à 29 km de ce lieu d’intérêt : Agence ITER ... (836 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 41440, 43.7496562, 6.3285616, '2025-11-19', 6.357142857142857, 8.378571428571428, 43.78041, 6.00644),
#  (18, 'Gorges du Verdon', 'https://www.booking.com/hotel/fr/chambre-d-39-hotes-les-lauriers-moustiers-sainte-marie1.fr.html', '"Les Lauriers" chambre indépendante avec terrasse privée', 9.1, 'Chemin de Quinson, 04360 Moustiers-Sainte-Marie, France', 'La Chambre D\'Hôtes "Les Lauriers" chambre indépendante avec terrasse privée propose un hébergement à Moustiers-Sainte-Marie.\n\nToutes les chambres  ... (361 characters truncated) ...  lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l\'établissement sont calculées avec © OpenStreetMap.', 41440, 43.7496562, 6.3285616, '2025-11-19', 6.357142857142857, 8.378571428571428, 43.83864, 6.21733),
#  (19, 'Gorges du Verdon', 'https://www.booking.com/hotel/fr/le-petit-grillo-gite-proche-du-verdon.fr.html', 'Gite avec terrasse privée proche des gorges du Verdon', 9.4, '1229 Chemin Saint-Véran, 04500 Allemagne-en-Provence, France', "Situé à Allemagne-en-Provence, l’hébergement Gite avec terrasse privée proche des gorges du Verdon offre une vue sur la montagne. Il propose un jardi ... (934 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 41440, 43.7496562, 6.3285616, '2025-11-19', 6.357142857142857, 8.378571428571428, 43.79148, 6.02613),
#  (20, 'Ariege', 'https://www.booking.com/hotel/fr/malepere.fr.html', 'Malepère', 8.3, 'Hameau de Montcabirol, 09500 La Bastide-de-Bousignac, France', "Situé à La Bastide-de-Bousignac, l’hébergement Malepère offre une vue sur le jardin. Il comprend une piscine extérieure ouverte en saison, un jardin, ... (908 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 91960, 42.9455368, 1.4065544, '2025-11-19', 1.5714285714285714, 10.828571428571427, 43.05472, 1.84864),
#  (21, 'Ariege', 'https://www.booking.com/hotel/fr/chambre-d-hotes-cantariege.fr.html', "Chambre d'Hôtes La Bourdasse", 9.5, "Chambre d'Hôtes La Bourdasse - 1720 Route de Crampagna , 09120 Loubens, France", "L’établissement Chambre d'Hôtes La Bourdasse se situe à Loubens, à 38 km de ce lieu d’intérêt : Col de la Crouzette. Il possède un salon commun, une  ... (1031 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 91960, 42.9455368, 1.4065544, '2025-11-19', 1.5714285714285714, 10.828571428571427, 43.03197, 1.55618),
#  (22, 'Ariege', 'https://www.booking.com/hotel/fr/chalet-pyreneen.fr.html', 'Chalet Pyrénéen', 8.4, '1776 Route de Saint Sernin, 09210 Saint-Ybars, France', "Situé à Saint-Ybars, l’hébergement Chalet Pyrénéen propose un jardin, une terrasse et un restaurant. Ce chalet possède un parking privé gratuit et se ... (637 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 91960, 42.9455368, 1.4065544, '2025-11-19', 1.5714285714285714, 10.828571428571427, 43.2173, 1.41062),
#  (23, 'Ariege', 'https://www.booking.com/hotel/fr/gite-dans-un-hameau-de-charme.fr.html', 'Gite dans un hameau de charme', 9.4, '1 Hameau de Cazalas, 09420 Castelnau-Durban, France', "Offrant une vue sur la montagne, l’hébergement Gite dans un hameau de charme comprend une terrasse et un balcon, à environ 19 km de ce lieu d’intérêt ... (609 characters truncated) ... us proche (Aéroport de Carcassonne) est à 102 km. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 91960, 42.9455368, 1.4065544, '2025-11-19', 1.5714285714285714, 10.828571428571427, 42.98096, 1.31723),
#  (24, 'Ariege', 'https://www.booking.com/hotel/fr/le-grand-cerf-freychenet.fr.html', 'Le Grand Cerf - 4 Couchages', 9.4, 'Freychenet, 09300 Nalzen, France', "Situé à Nalzen, l’hébergement Le Grand Cerf - 4 Couchages met à votre disposition une connexion Wi-Fi gratuite et offre une vue sur le jardin. Cette  ... (739 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 91960, 42.9455368, 1.4065544, '2025-11-19', 1.5714285714285714, 10.828571428571427, 42.90831, 1.71981),
#  (25, 'Ariege', 'https://www.booking.com/hotel/fr/gite-de-montagne-en-ariege.fr.html', 'Gite de montagne en Ariège', 8.4, '16 route de castillon, 09800 Engomer, France', "Situé à Engomer, l’hébergement Gite de montagne en Ariège met à votre disposition une connexion Wi-Fi gratuite et offre une vue sur le jardin. Cet hé ... (518 characters truncated) ... oche (Aéroport de Toulouse-Blagnac) est à 108 km. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 91960, 42.9455368, 1.4065544, '2025-11-19', 1.5714285714285714, 10.828571428571427, 42.96332, 1.09341),
#  (26, 'Ariege', 'https://www.booking.com/hotel/fr/belloreade.fr.html', "Belloréade Maison d'hôtes", 9.5, 'Chemin du Carme, 09600 Belloc, France', "Situé à Belloc (Midi-Pyrénées), l’établissement Belloréade Maison d'hôtes comprend une connexion Wi-Fi gratuite, un parking privé gratuit et un bain  ... (762 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 91960, 42.9455368, 1.4065544, '2025-11-19', 1.5714285714285714, 10.828571428571427, 43.013, 1.92661),
#  (27, 'Ariege', 'https://www.booking.com/hotel/fr/le-domaine-d-arignac.fr.html', "Le Domaine d'Arignac", 8.9, '30 Route de Foix, 09400 Arignac, France', "L’établissement Le Domaine d'Arignac se situe à Arignac (Midi-Pyrénées), à 37 km de ce lieu d’intérêt : Col de la Crouzette. Il possède une connexion ... (687 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 91960, 42.9455368, 1.4065544, '2025-11-19', 1.5714285714285714, 10.828571428571427, 42.86755, 1.60283),
#  (28, 'Ariege', 'https://www.booking.com/hotel/fr/loft-en-bois-pour-3-personnes.fr.html', 'Reflet de Bien Être', 8.4, '17 Route des Pyrenees, 31260 Marsoulas, France', "L’hébergement Reflet de Bien Être vous accueille à Marsoulas, à seulement 45 km de ce lieu d’intérêt : Col de la Crouzette. Il comprend un jardin, un ... (623 characters truncated) ... roche (Aéroport de Toulouse-Blagnac) est à 81 km. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 91960, 42.9455368, 1.4065544, '2025-11-19', 1.5714285714285714, 10.828571428571427, 43.07488, 0.95224),
#  (29, 'Ariege', 'https://www.booking.com/hotel/fr/tente-skylodge-skali.fr.html', "D'tente skylodge SKALI", 9.8, 'Massat, 09320 Massat, France', "L’hébergement D'tente skylodge SKALI vous accueille à Massat, à seulement 10 km de ce lieu d’intérêt : Col de la Crouzette. Il comprend un jardin, un ... (792 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 91960, 42.9455368, 1.4065544, '2025-11-19', 1.5714285714285714, 10.828571428571427, 42.89074, 1.34832),
#  (30, 'Ariege', 'https://www.booking.com/hotel/fr/t2-residence-grand-appt-308-aulus-les-bains.fr.html', 'Le Valier, T2 résidence Grand Hôtel - Appt 308 - Aulus-les-bains', 9.2, 'Appartement 308 Rue Principale, 09140 Aulus-les-Bains, France', "Doté d’un sauna, l’hébergement Le Valier, T2 résidence Grand Hôtel - Appt 308 - Aulus-les-bains se situe à Aulus-les-Bains, à 31 km de ce lieu d’inté ... (732 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 91960, 42.9455368, 1.4065544, '2025-11-19', 1.5714285714285714, 10.828571428571427, 42.79039, 1.33731),
#  (31, 'Ariege', 'https://www.booking.com/hotel/fr/elegant-et-moderne.fr.html', 'Elégant et moderne', 8.9, '28 Cours Bouycheres, 09000 Foix, France', "Proposant un jardin et offrant une vue sur la ville, l’hébergement Elégant et moderne vous accueille à Foix, à respectivement 600 mètres et 6,5 km de ... (767 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 91960, 42.9455368, 1.4065544, '2025-11-19', 1.5714285714285714, 10.828571428571427, 42.96523, 1.6106),
#  (32, 'Ariege', 'https://www.booking.com/hotel/fr/le-nopal-bleu.fr.html', 'Le Nopal Bleu', 9.3, '10 Rue des Fontanelles, 09400 Tarascon-sur-Ariège, France', "Situé à Tarascon-sur-Ariège, l’hébergement Le Nopal Bleu met à votre disposition une connexion Wi-Fi gratuite et offre une vue sur la montagne. Cet h ... (600 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 91960, 42.9455368, 1.4065544, '2025-11-19', 1.5714285714285714, 10.828571428571427, 42.84865, 1.60716),
#  (33, 'Ariege', 'https://www.booking.com/hotel/fr/la-note-verte-pause-en-ville.fr.html', "La Note Verte - Parking gratuit devant l'entrée", 9.4, '4 Rue Petite des Ruisseaux, 09000 Foix, France', "L’hébergement La Note Verte - Parking gratuit devant l'entrée se trouve à Foix, à respectivement 600 mètres, 7,9 km et 17 km de ces lieux d’intérêt : ... (775 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 91960, 42.9455368, 1.4065544, '2025-11-19', 1.5714285714285714, 10.828571428571427, 42.96118, 1.60729),
#  (34, 'Ariege', 'https://www.booking.com/hotel/fr/appartment-cocoon-52-m-2-new-heart-of-the-city.fr.html', 'cocoon 52 m2 new, beautiful view castle and mountain', 9.4, '9 Avenue de Lérida, 09000 Foix, France', "L’hébergement cocoon 52 m2 new, beautiful view castle and mountain se trouve à Foix, à seulement 300 mètres de ce lieu d’intérêt : Château de Foix. I ... (726 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 91960, 42.9455368, 1.4065544, '2025-11-19', 1.5714285714285714, 10.828571428571427, 42.96451, 1.60275),
#  (35, 'Ariege', 'https://www.booking.com/hotel/fr/le-petit-nid-montgaillard.fr.html', 'Le petit nid', 8.9, 'RDC 1 Rue de la Place, 09330 Montgaillard, France', "Offrant une vue sur le jardin, l’hébergement Le petit nid se situe à Montgaillard, à respectivement 38 km et 5 km de ces lieux d’intérêt : Col de la  ... (704 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 91960, 42.9455368, 1.4065544, '2025-11-19', 1.5714285714285714, 10.828571428571427, 42.93228, 1.63504),
#  (36, 'Ariege', 'https://www.booking.com/hotel/fr/la-forge-d-espy.fr.html', "La Forge d'Espy", 9.9, "4 rue des forgerons Laramade d'en Bas, 09220 Illier-et-Laramade, France", "L’hébergement La Forge d'Espy se trouve à Illier-et-Laramade, à 44 km de ce lieu d’intérêt : Col de la Crouzette. Il propose un jardin, une connexion ... (737 characters truncated) ... lus proche (Aéroport de Carcassonne) est à 99 km. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 91960, 42.9455368, 1.4065544, '2025-11-19', 1.5714285714285714, 10.828571428571427, 42.78451, 1.55947),
#  (37, 'Ariege', 'https://www.booking.com/hotel/fr/la-grange-carla-de-roquefort.fr.html', 'La Grange - 10 couchages', 8.7, '9 Le Barry, 09300 Carla-de-Roquefort, France', "Offrant une vue sur la ville, l’hébergement La Grange - 10 couchages comprend une terrasse et un balcon, à environ 20 km de ce lieu d’intérêt : Châte ... (610 characters truncated) ... lus proche (Aéroport de Carcassonne) est à 64 km. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 91960, 42.9455368, 1.4065544, '2025-11-19', 1.5714285714285714, 10.828571428571427, 42.97539, 1.76528),
#  (38, 'Ariege', 'https://www.booking.com/hotel/fr/loft-at-besset.fr.html', 'loft At Besset', 7.7, 'Las Graoussos, 09500 Besset, France', "Proposant une terrasse et offrant une vue sur le jardin, l’hébergement loft At Besset vous accueille à Besset, à respectivement 30 km et 32 km de ces ... (828 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 91960, 42.9455368, 1.4065544, '2025-11-19', 1.5714285714285714, 10.828571428571427, 43.08312, 1.84589),
#  (39, 'Ariege', 'https://www.booking.com/hotel/fr/ourson-ax-les-thermes1.fr.html', 'Résidence Maurice', 8.7, '14 Rue François Mansard, 09110 Ax-les-Thermes, France', "Proposant une terrasse, un accès skis aux pieds et une connexion Wi-Fi gratuite, l’établissement Résidence Maurice se trouve à Ax-les-Thermes, à resp ... (777 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 91960, 42.9455368, 1.4065544, '2025-11-19', 1.5714285714285714, 10.828571428571427, 42.72071, 1.83819),
#  (40, 'Carcassonne', 'https://www.booking.com/hotel/fr/des-trois-couronnes.fr.html', 'Tribe Carcassonne', 8.0, '2 Rue Des Trois Couronnes, 11000 Carcassonne, France', "Bénéficiant d’un emplacement privilégié dans la ville basse de Carcassonne, où vous pourrez découvrir tous les secrets de la cité médiévale dans un c ... (679 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 110690, 43.2130358, 2.3491069, '2025-11-19', 0.0285714285714285, 14.37142857142857, 43.2103, 2.35772),
#  (41, 'Carcassonne', 'https://www.booking.com/hotel/fr/inter-les-oliviers.fr.html', 'ibis Styles Carcassonne La Cité', 8.4, '2 rue Darius Milhaud , 11000 Carcassonne, France', "ibis Styles Carcassonne La Cité is located just 700 metres from the medieval city of Carcassonne. It features a restaurant, an outdoor swimming pool, ... (710 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 110690, 43.2130358, 2.3491069, '2025-11-19', 0.0285714285714285, 14.37142857142857, 43.20761, 2.37273),
#  (42, 'Carcassonne', 'https://www.booking.com/hotel/fr/soleilvacances-du-roi.fr.html', 'Hotel du Roi & Spa by SOWELL COLLECTION', 8.4, '3 Rue des Calquières, 11000 Carcassonne, France', "Situé à Carcassonne, l’établissement 5 étoiles Hotel du Roi & Spa by SOWELL COLLECTION possède un jardin, un restaurant et un bar. Il vous accueille  ... (1005 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 110690, 43.2130358, 2.3491069, '2025-11-19', 0.0285714285714285, 14.37142857142857, 43.21084, 2.35777),
#  (43, 'Carcassonne', 'https://www.booking.com/hotel/fr/carcassonne-porte-de-la-cite.fr.html', 'Mercure Carcassonne La Cité', 8.6, '18 Rue Camille Saint-Saens, 11000 Carcassonne, France', "Offrant une vue sur les remparts de la ville, le Mercure Carcassonne La Cité est situé à seulement 4 minutes à pied du quartier médiéval de Carcasson ... (843 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 110690, 43.2130358, 2.3491069, '2025-11-19', 0.0285714285714285, 14.37142857142857, 43.20678, 2.36956),
#  (44, 'Carcassonne', 'https://www.booking.com/hotel/fr/good-knight.fr.html', 'GOOD KNIGHT', 8.7, '17 montée gaston combelean, 11000 Carcassonne, France', "L’établissement GOOD KNIGHT se trouve à Carcassonne, à 50 km de ce lieu d’intérêt : Termes Chateau. Il propose un jardin, une terrasse et un parking  ... (661 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 110690, 43.2130358, 2.3491069, '2025-11-19', 0.0285714285714285, 14.37142857142857, 43.20774, 2.36717),
#  (45, 'Carcassonne', 'https://www.booking.com/hotel/fr/soleil-vacances-les-chevaliers.fr.html', 'SOWELL HOTELS Les Chevaliers', 8.2, '2 bis Rue des Calquières, 11000 Carcassonne, France', "Situé à Carcassonne, à 2\xa0minutes à pied de l'Aude et offrant une vue sur le pont Vieux, le SOWELL HOTELS Les Chevaliers propose une connexion Wi-F ... (651 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 110690, 43.2130358, 2.3491069, '2025-11-19', 0.0285714285714285, 14.37142857142857, 43.21103, 2.35824),
#  (46, 'Carcassonne', 'https://www.booking.com/hotel/fr/ledonjon.fr.html', 'Hôtel Le Donjon - Cœur de La Cité Médiévale', 8.4, '2 Rue Du Comte Roger, La Cité, 11000 Carcassonne, France', "Situé au cœur de la cité médiévale de Carcassonne, l'hôtel Le Donjon - Cœur de La Cité Médiévale est entouré par les anciens remparts de la ville. Ce ... (1033 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 110690, 43.2130358, 2.3491069, '2025-11-19', 0.0285714285714285, 14.37142857142857, 43.20636, 2.36387),
#  (47, 'Carcassonne', 'https://www.booking.com/hotel/fr/loft-spa-cote-cite.fr.html', 'LOFT SPA - Côté château.', 8.5, '34 RUE MOLIERE, 11000 Carcassonne, France', "Situé à Carcassonne, le LOFT SPA - Côté cité se trouve à 10 minutes à pied de la ville fortifiée médiévale de Carcassonne. Tous les logements dispose ... (837 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 110690, 43.2130358, 2.3491069, '2025-11-19', 0.0285714285714285, 14.37142857142857, 43.21078, 2.36806),
#  (48, 'Carcassonne', 'https://www.booking.com/hotel/fr/montmorency.fr.html', 'Hôtel Montmorency & Spa', 8.1, '2 Rue Camille Saint Saens, 11000 Carcassonne, France', "Situé à 30 mètres de l'entrée de la cité médiévale de Carcassonne, l'Hôtel Montmorency propose une connexion Wi-Fi gratuite, une piscine extérieure e ... (776 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 110690, 43.2130358, 2.3491069, '2025-11-19', 0.0285714285714285, 14.37142857142857, 43.20712, 2.367),
#  (49, 'Carcassonne', 'https://www.booking.com/hotel/fr/l-aragon.fr.html', "Hôtel l'Aragon", 8.5, '15 montée Combeleran, 11000 Carcassonne, France', "Situé à seulement 50 mètres du centre historique de Carcassonne dans l'Aude, l'hôtel l'Aragon propose une connexion Wi-Fi gratuite dans l'ensemble de ... (644 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 110690, 43.2130358, 2.3491069, '2025-11-19', 0.0285714285714285, 14.37142857142857, 43.20788, 2.3673),
#  (50, 'Carcassonne', 'https://www.booking.com/hotel/fr/le-coeur-de-la-bastide.fr.html', 'Le Cœur de la Bastide - Adult only', 9.4, '53 rue de la République, 11000 Carcassonne, France', "L’établissement Le Cœur de la Bastide - Adult only vous accueille à Carcassonne, à respectivement 50 km et 300 mètres de ces lieux d’intérêt : Termes ... (646 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 110690, 43.2130358, 2.3491069, '2025-11-19', 0.0285714285714285, 14.37142857142857, 43.21415, 2.35002),
#  (51, 'Carcassonne', 'https://www.booking.com/hotel/fr/hotel-de-la-cite.fr.html', 'Hotel de la Cité Carcassonne - MGallery Collection', 8.9, 'Place Auguste Pierre Pont, 11000 Carcassonne, France', "L’Hotel de la Cité & Spa MGallery vous accueille dans un château de style médiéval situé à l’intérieur des remparts de Carcassonne. L’hôtel possède u ... (1413 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 110690, 43.2130358, 2.3491069, '2025-11-19', 0.0285714285714285, 14.37142857142857, 43.20527, 2.36321),
#  (52, 'Carcassonne', 'https://www.booking.com/hotel/fr/domitys-carmina.fr.html', 'DOMITYS - Carmina', 9.4, '29 Av. du Général Leclerc, 11000 Carcassonne, France', "L’établissement DOMITYS - Carmina vous accueille à Carcassonne, à respectivement 1,3 km et 1,3 km de ces lieux d’intérêt : Memorial House (Maison des ... (925 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 110690, 43.2130358, 2.3491069, '2025-11-19', 0.0285714285714285, 14.37142857142857, 43.21013, 2.365),
#  (53, 'Carcassonne', 'https://www.booking.com/hotel/fr/harmony-3.fr.html', 'Situation exceptionnelle HARMONY III', 9.9, '1er étage appart 3 43 Rue Aimé Ramond, 11000 Carcassonne, France', "L’établissement Situation exceptionnelle HARMONY III vous accueille à Carcassonne, à respectivement 200 mètres et 500 mètres de ces lieux d’intérêt : ... (797 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 110690, 43.2130358, 2.3491069, '2025-11-19', 0.0285714285714285, 14.37142857142857, 43.21174, 2.35219),
#  (54, 'Carcassonne', 'https://www.booking.com/hotel/fr/republique-centre.fr.html', 'REPUBLIQUE Centre', 8.7, '5 Rue de la République, 11000 Carcassonne, France', "L’établissement REPUBLIQUE Centre se trouve à Carcassonne, à proximité de ces lieux d’intérêt : Memorial House (Maison des Memoires), Cathédrale Sain ... (632 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 110690, 43.2130358, 2.3491069, '2025-11-19', 0.0285714285714285, 14.37142857142857, 43.21418, 2.35437),
#  (55, 'Carcassonne', 'https://www.booking.com/hotel/fr/de-l-octroi.fr.html', "Hôtel De L'octroi", 8.3, '143 rue Trivalle, 11000 Carcassonne, France', "L'Hôtel De L'octroi est situé à 150\xa0mètres de l'entrée de la cité médiévale de Carcassonne. L’établissement propose des chambres modernes avec con ... (929 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 110690, 43.2130358, 2.3491069, '2025-11-19', 0.0285714285714285, 14.37142857142857, 43.20867, 2.36832),
#  (56, 'Carcassonne', 'https://www.booking.com/hotel/fr/la-maison-de-la-tour-pinte.fr.html', 'La Maison de La Tour Pinte', 9.9, '24 Rue Longue, 11000 Carcassonne, France', "Situé à Carcassonne, l’hébergement avec climatisation La Maison de La Tour Pinte possède un balcon. Cette villa comprend une piscine privée, un jardi ... (626 characters truncated) ... plus proche (Aéroport de Carcassonne) est à 5 km. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 110690, 43.2130358, 2.3491069, '2025-11-19', 0.0285714285714285, 14.37142857142857, 43.20577, 2.36099),
#  (57, 'Carcassonne', 'https://www.booking.com/hotel/fr/ibis-carcassonne-centre.fr.html', 'ibis Carcassonne Centre - La Cité', 7.1, '5, square Gambetta, 11000 Carcassonne, France', "L'ibis Carcassonne Centre bénéficie d'un emplacement idéal à 1 km de la gare de Carcassonne et à seulement 800 mètres du cœur médiéval de la ville. I ... (1252 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 110690, 43.2130358, 2.3491069, '2025-11-19', 0.0285714285714285, 14.37142857142857, 43.2116, 2.35744),
#  (58, 'Carcassonne', 'https://www.booking.com/hotel/fr/le-loft-de-la-tour-pinte.fr.html', 'Le Loft de La Tour Pinte', 9.8, '70 Rue Barbacane, 11000 Carcassonne, France', "Offrant une vue sur la ville, l’hébergement Le Loft de La Tour Pinte propose une terrasse et un balcon, à environ 50 km de ce lieu d’intérêt : Termes ... (887 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 110690, 43.2130358, 2.3491069, '2025-11-19', 0.0285714285714285, 14.37142857142857, 43.20765, 2.36124),
#  (59, 'Carcassonne', 'https://www.booking.com/hotel/fr/kyriad-carcassonne-ouest-la-cita-c-xml.fr.html', 'Kyriad Carcassonne - Aéroport', 8.0, 'Allée Gilles Personnier De Roberval, 11000 Carcassonne, France', "L’établissement Kyriad Carcassonne - Aéroport se situe à Carcassonne, à 3,9 km de ce lieu d’intérêt : IUT de Perpignan - Campus de Carcassonne. Il po ... (925 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 110690, 43.2130358, 2.3491069, '2025-11-19', 0.0285714285714285, 14.37142857142857, 43.20863, 2.31242),
#  (60, 'Aix en Provence', 'https://www.booking.com/hotel/fr/residence-mirabeau.fr.html', 'Séjours & Affaires Aix-en-Provence Mirabeau', 7.9, '615 Avenue Wolfgang Amadeus Mozart, 13100 Aix-en-Provence, France', "Cette résidence Séjours & Affaires est située à Aix-en-Provence, à proximité du cours Mirabeau. Elle propose des studios meublés et une connexion Wi- ... (473 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 130010, 43.5298424, 5.4474738, '2025-11-19', 6.528571428571428, 13.85, 43.52529, 5.44125),
#  (61, 'Aix en Provence', 'https://www.booking.com/hotel/fr/renaissance-aix-en-provence.fr.html', 'Renaissance Aix-en-Provence Hotel', 8.5, '256 Avenue Pérouse, 13100 Aix-en-Provence, France', "Situé à moins de 10 minutes à pied du centre d'Aix-en-Provence, le Renaissance Aix-en-Provence Hotel propose une réception ouverte 24h/24, des journa ... (841 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 130010, 43.5298424, 5.4474738, '2025-11-19', 6.528571428571428, 13.85, 43.52632, 5.43785),
#  (62, 'Aix en Provence', 'https://www.booking.com/hotel/fr/best-western-le-galice.fr.html', 'Best Western Hotel le Galice Aix-en-Provence', 8.0, '5 Route de Galice, 13090 Aix-en-Provence, France', "Situé à 10\xa0minutes à pied du centre d’Aix-en-Provence, le Best Western Hotel le Galice Aix-en-Provence dispose d’une piscine extérieure ouverte en ... (647 characters truncated) ...  disponible, moyennant des frais supplémentaires. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 130010, 43.5298424, 5.4474738, '2025-11-19', 6.528571428571428, 13.85, 43.52812, 5.43442),
#  (63, 'Aix en Provence', 'https://www.booking.com/hotel/fr/hotel-aquabella.fr.html', 'Aquabella Hôtel & Spa', 8.7, '2, Rue des Etuves, 13100 Aix-en-Provence, France', "Entouré d’un beau jardin, l’Aquabella Hôtel\xa0&\xa0Spa propose des chambres de style provençal. Vous pourrez accéder gratuitement au spa. Vous séjou ... (750 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 130010, 43.5298424, 5.4474738, '2025-11-19', 6.528571428571428, 13.85, 43.53106, 5.44489),
#  (64, 'Aix en Provence', 'https://www.booking.com/hotel/fr/chateau-de-la-gaude.fr.html', 'Château de la Gaude', 9.1, '3959 route des Pinchinats, 13100 Aix-en-Provence, France', "L’établissement Château de la Gaude se situe à Aix-en-Provence, à 38 km de ce lieu d’intérêt : Gare de Marseille-Saint-Charles. Il possède une piscin ... (1334 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 130010, 43.5298424, 5.4474738, '2025-11-19', 6.528571428571428, 13.85, 43.56895, 5.479),
#  (65, 'Aix en Provence', 'https://www.booking.com/hotel/fr/rotonde.fr.html', 'Hôtel Rotonde Aix-en-Provence centre', 8.2, '15 avenue Des Belges, 13100 Aix-en-Provence, France', "L’Hôtel Rotonde Aix-en-Provence centre est situé dans le centre d’Aix-en-Provence, à 5\xa0minutes à pied de la gare routière.\n\nUne connexion Wi-Fi  ... (651 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 130010, 43.5298424, 5.4474738, '2025-11-19', 6.528571428571428, 13.85, 43.52389, 5.44252),
#  (66, 'Aix en Provence', 'https://www.booking.com/hotel/fr/grand-mercure-roi-rene.fr.html', 'Grand Hôtel Roi René Aix - MGallery Collection', 8.5, '24 Boulevard du Roi René, 13100 Aix-en-Provence, France', "Situé à seulement 5\xa0minutes à pied du cours Mirabeau et du centre-ville d’Aix-en-Provence, le Grand Hôtel Roi René Aix en Provence Centre\xa0-\xa0 ... (1206 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 130010, 43.5298424, 5.4474738, '2025-11-19', 6.528571428571428, 13.85, 43.52359, 5.44981),
#  (67, 'Aix en Provence', 'https://www.booking.com/hotel/fr/atrium-d-anaite.fr.html', "Appart Hotel Odalys City Aix en Provence L'Atrium", 8.0, '15 Cours Gambetta - Espace Forbin, 13100 Aix-en-Provence, France', "Situé à Aix-en-Provence, l’Cours Mirabeau, Appart Hotel Odalys City Aix en Provence L’Atrium propose des appartements offrant 1\xa0chambre et des stu ... (1027 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 130010, 43.5298424, 5.4474738, '2025-11-19', 6.528571428571428, 13.85, 43.5242, 5.45519),
#  (68, 'Aix en Provence', 'https://www.booking.com/hotel/fr/les-augustins.fr.html', 'Hôtel des Augustins', 8.3, '3 Rue De La Masse, 13100 Aix-en-Provence, France', "Situé à côté du célèbre cours Mirabeau, au cœur de la vieille ville d'Aix-en-Provence, l'Hôtel Les Augustins se trouve dans les murs d'un couvent dat ... (631 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 130010, 43.5298424, 5.4474738, '2025-11-19', 6.528571428571428, 13.85, 43.52694, 5.44718),
#  (69, 'Aix en Provence', 'https://www.booking.com/hotel/fr/la-caravelle-aix-en-provence.fr.html', 'La Caravelle', 8.3, '29, boulevard du Roi René, 13100 Aix-en-Provence, France', "Situé au cœur d’Aix-en-Provence, l’hôtel La Caravelle vous accueille à moins de 8\xa0minutes à pied du Cours Mirabeau, du Musée Granet et du Palais d ... (776 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 130010, 43.5298424, 5.4474738, '2025-11-19', 6.528571428571428, 13.85, 43.52484, 5.45363),
#  (70, 'Aix en Provence', 'https://www.booking.com/hotel/fr/pierre-vacances-city-centre.fr.html', 'Aparthotel Adagio Aix-en-Provence Centre', 8.5, '3/5, rue des Chartreux, 13100 Aix-en-Provence, France', "L'Aparthotel Adagio Aix-en-Provence Centre se situe dans une rue paisible du centre de la commune d'Aix-en-Provence, à 10 minutes à pied des cafés et ... (956 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 130010, 43.5298424, 5.4474738, '2025-11-19', 6.528571428571428, 13.85, 43.52898, 5.44088),
#  (71, 'Aix en Provence', 'https://www.booking.com/hotel/fr/hotel-escaletto.fr.html', 'Hôtel Escaletto', 8.3, '74, cours Sextius, 13100 Aix-en-Provence, France', "Établissement 3\xa0étoiles, l’Hôtel Escaletto vous accueille dans le centre-ville d’Aix-en-Provence, à 1\xa0minute à pied des Thermes Sextius et à 55 ... (598 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 130010, 43.5298424, 5.4474738, '2025-11-19', 6.528571428571428, 13.85, 43.53012, 5.44411),
#  (72, 'Aix en Provence', 'https://www.booking.com/hotel/fr/paul.fr.html', 'Hôtel Paul', 8.5, '10 avenue Pasteur, 13100 Aix-en-Provence, France', "Situé au cœur d'Aix-en-Provence, l'Hôtel Paul est situé à seulement 150 mètres du spa, du Palais des Festivals et du quartier historique de la ville. ... (934 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 130010, 43.5298424, 5.4474738, '2025-11-19', 6.528571428571428, 13.85, 43.53332, 5.44607),
#  (73, 'Aix en Provence', 'https://www.booking.com/hotel/fr/le-set.fr.html', 'Setclub Hôtel & Spa Aix-en-Provence', 8.0, '1335 Chemin de Granet, 13090 Aix-en-Provence, France', "L’établissement Setclub Hôtel & Spa Aix-en-Provence se situe à Aix-en-Provence, à 34 km de ce lieu d’intérêt : Gare de Marseille-Saint-Charles. Il po ... (1314 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 130010, 43.5298424, 5.4474738, '2025-11-19', 6.528571428571428, 13.85, 43.54395, 5.38856),
#  (74, 'Aix en Provence', 'https://www.booking.com/hotel/fr/golden-tulip-aix-en-provence.fr.html', 'Radisson Hotel Aix En Provence', 7.9, '42 ROUTE DE GALICE, 13090 Aix-en-Provence, France', "Le Radisson Aix en Provence est situé à la sortie des autoroutes A8 et A51. Il est implanté à seulement 10\xa0minutes de route du centre d’Aix-en-Pro ... (1048 characters truncated) ... st disponible moyennant des frais supplémentaires Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 130010, 43.5298424, 5.4474738, '2025-11-19', 6.528571428571428, 13.85, 43.52855, 5.42504),
#  (75, 'Aix en Provence', 'https://www.booking.com/hotel/fr/grand-negre-coste.fr.html', 'Negrecoste Hôtel & Spa', 8.1, '33, Cours Mirabeau, 13100 Aix-en-Provence, France', "Doté d’une terrasse bien exposée, le Negrecoste Hôtel\xa0& Spa est un établissement du XVIIIe\xa0siècle situé au cœur du cours Mirabeau, à 10\xa0minu ... (1255 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 130010, 43.5298424, 5.4474738, '2025-11-19', 6.528571428571428, 13.85, 43.52697, 5.44897),
# ...
#  (674, 'Mont Saint Michel', 'https://www.booking.com/hotel/fr/mon-saint-michel.fr.html', 'Mon Saint Michel', 8.7, '28 route de la Rive, 50170 Ardevon, France', "Offrant une vue sur le jardin, l’établissement Mon Saint Michel possède une connexion Wi-Fi gratuite et un parking privé gratuit. Il se situe à Ardev ... (879 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 5035351, 48.6359541, -1.51146, '2025-11-19', 2.6714285714285717, 11.271428571428572, 48.61361, -1.48608),
#  (675, 'Mont Saint Michel', 'https://www.booking.com/hotel/fr/auberge-de-la-baie.fr.html', 'Auberge de la Baie', 8.4, 'La Rive – D275, 50170 Ardevon, France', "Situé dans la campagne normande, cet hôtel dispose d’une connexion Wi-Fi gratuite.\n\nToutes les chambres modernes de l'Auberge de la Baie sont équip ... (431 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 5035351, 48.6359541, -1.51146, '2025-11-19', 2.6714285714285717, 11.271428571428572, 48.60185, -1.47418),
#  (676, 'Mont Saint Michel', 'https://www.booking.com/hotel/fr/le-marquis-de-la-guintre.fr.html', 'Le Marquis De La Guintre', 8.7, '75 route du mont saint michel, 50220 Courtils, France', "Situé à Courtils, l’établissement Le Marquis De La Guintre propose une connexion Wi-Fi gratuite, une terrasse, un restaurant et un bar.\n\nUn petit-d ... (323 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 5035351, 48.6359541, -1.51146, '2025-11-19', 2.6714285714285717, 11.271428571428572, 48.6248, -1.44538),
#  (677, 'Mont Saint Michel', 'https://www.booking.com/hotel/fr/a-l-ombre-du-mont-saint-michel.fr.html', "A l'ombre du Mont Saint Michel - Bed & Breakfast, Chambres d'hôtes", 9.5, '7 Rue du Pont Landais, 50170 Huisnes-sur-Mer, France', "Situé à Huisnes-sur-Mer, l’établissement A l'ombre du Mont Saint Michel - Bed & Breakfast, Chambres d'hôtes possède une connexion Wi-Fi gratuite, un  ... (752 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 5035351, 48.6359541, -1.51146, '2025-11-19', 2.6714285714285717, 11.271428571428572, 48.6159, -1.46553),
#  (678, 'Mont Saint Michel', 'https://www.booking.com/hotel/fr/maison-au-pied-du-mont-saint-michel.fr.html', 'Maison au pied du Mont Saint Michel', 9.3, '15 Route de la Rive Ardevon, 50170 Pontorson, France', "L’hébergement Maison au pied du Mont Saint Michel vous accueille à Pontorson, à respectivement 8,7 km et 21 km de ces lieux d’intérêt : Mont Saint-Mi ... (771 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 5035351, 48.6359541, -1.51146, '2025-11-19', 2.6714285714285717, 11.271428571428572, 48.60133, -1.47416),
#  (679, 'Mont Saint Michel', 'https://www.booking.com/hotel/fr/gites-bellevue.fr.html', 'Gites Bellevue', 9.0, 'Ferme Bellevue, 50170 Beauvoir, France', "Situé à seulement 2 km du célèbre Mont-Saint-Michel, l'établissement Gites Bellevue vous propose des gîtes indépendants avec terrasse, jardin et barb ... (600 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 5035351, 48.6359541, -1.51146, '2025-11-19', 2.6714285714285717, 11.271428571428572, 48.60806, -1.51723),
#  (680, 'Biarritz', 'https://www.booking.com/hotel/fr/hotelargieder.fr.html', 'Hôtel Barnea', 9.0, '13 rue Peyroloubilh, 64200 Biarritz, France', "L'Hotel Hôtel Barnea se situe dans le centre de Biarritz, à seulement 3 minutes à pied de la plage, des commerces et des restaurants.\n\nLes chambres ... (356 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 6402481, 43.4711438, -1.5527266, '2025-11-19', 3.5142857142857147, 15.35, 43.48067, -1.56419),
#  (681, 'Biarritz', 'https://www.booking.com/hotel/fr/le-cafe-de-paris-4.fr.html', 'Hôtel Le Café de Paris', 9.0, 'Place Bellevue, 64200 Biarritz, France', "L'Hôtel Le Café de Paris est situé dans le centre de Biarritz, sur la place piétonne Bellevue et à 5\xa0minutes à pied des Halles. Toutes les chambre ... (484 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 6402481, 43.4711438, -1.5527266, '2025-11-19', 3.5142857142857147, 15.35, 43.4827, -1.56097),
#  (682, 'Biarritz', 'https://www.booking.com/hotel/fr/tonic-hotel-biarritz.fr.html', 'Grand Tonic Hotel & SPA NUXE', 7.9, '58 Avenue Edouard VII, 64200 Biarritz, France', "Situé dans la ville balnéaire de Biarritz, le Grand Tonic Hotel\xa0&\xa0SPA Biarritz se trouve à seulement 200\xa0mètres de la Grande Plage pour un s ... (1452 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 6402481, 43.4711438, -1.5527266, '2025-11-19', 3.5142857142857147, 15.35, 43.48459, -1.55658),
#  (683, 'Biarritz', 'https://www.booking.com/hotel/fr/residence-pierre-vacances-haguna.fr.html', 'Résidence Pierre & Vacances Premium Haguna', 8.5, '17, Avenue De La Reine Victoria, 64200 Biarritz, France', "L’établissement Pierre\xa0& Vacances Premium Haguna se trouve dans le centre-ville de Biarritz, à seulement 300\xa0mètres de la plage. Cette résidenc ... (1390 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 6402481, 43.4711438, -1.5527266, '2025-11-19', 3.5142857142857147, 15.35, 43.48541, -1.55251),
#  (684, 'Biarritz', 'https://www.booking.com/hotel/fr/best-western-kemaris.fr.html', 'Hôtel Kemaris', 8.4, '35 Avenue du Maréchal Joffre, 64200 Biarritz, France', "Alliant un cadre animé, de nombreux équipements et une ambiance chaleureuse, l’Hôtel Kemaris présente une architecture typique du Pays Basque.\n\nLes ... (982 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 6402481, 43.4711438, -1.5527266, '2025-11-19', 3.5142857142857147, 15.35, 43.47647, -1.56225),
#  (685, 'Biarritz', 'https://www.booking.com/hotel/fr/la-maison-du-lierre.fr.html', 'Hôtel & Espace Bien-être La Maison du Lierre', 9.0, '3 avenue du Jardin Public, 64200 Biarritz, France', "L’Hôtel\xa0&\xa0Espace Bien-être La Maison du Lierre se trouve à Biarritz, à 300\xa0mètres de la plage ainsi qu’à 5\xa0minutes du centre de congrès B ... (775 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 6402481, 43.4711438, -1.5527266, '2025-11-19', 3.5142857142857147, 15.35, 43.48014, -1.56075),
#  (686, 'Biarritz', 'https://www.booking.com/hotel/fr/de-la-plage-biarritz.fr.html', 'Hôtel de La Plage', 9.3, '3, esplanade du Port Vieux, 64200 Biarritz, France', "L'Hôtel de la Plage vous accueille à Biarritz, en face de l'océan et à seulement 50 mètres de la plage du vieux-port. Il propose des chambres dotées  ... (704 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 6402481, 43.4711438, -1.5527266, '2025-11-19', 3.5142857142857147, 15.35, 43.48207, -1.56755),
#  (687, 'Biarritz', 'https://www.booking.com/hotel/fr/karitza-biarritz.fr.html', 'Hôtel Jules Verne Biarritz', 8.3, '2, rue Guy Petit, 64200 Biarritz, France', "L’Hôtel Jules Verne Biarritz vous accueille dans le centre-ville de Biarritz, à proximité du Palais des Festivals, du casino et des plages. Sur place ... (877 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 6402481, 43.4711438, -1.5527266, '2025-11-19', 3.5142857142857147, 15.35, 43.47865, -1.55567),
#  (688, 'Biarritz', 'https://www.booking.com/hotel/fr/alcyon-biarritz.fr.html', 'Ama Hôtel', 8.8, '8 rue Maison Suisse, 64200 Biarritz, France', "Conçu par le célèbre architecte basque Raymond Larrebat-Tudor et construit au XVIIIe siècle, l’Ama Hôtel vous accueille dans une jolie résidence situ ... (507 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 6402481, 43.4711438, -1.5527266, '2025-11-19', 3.5142857142857147, 15.35, 43.48131, -1.55752),
#  (689, 'Biarritz', 'https://www.booking.com/hotel/fr/reginaexperimentalbiarritz.fr.html', 'Regina Experimental Biarritz', 8.7, "52 avenue de l'Impératrice, 64200 Biarritz, France", "Situé sur une falaise face à l'océan, le Regina Experimental surplombe la baie de Biarritz. Ses grands volumes préservés ont été intelligemment mêlés ... (758 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 6402481, 43.4711438, -1.5527266, '2025-11-19', 3.5142857142857147, 15.35, 43.49084, -1.55202),
#  (690, 'Biarritz', 'https://www.booking.com/hotel/fr/au-bon-coin-biarritz.fr.html', 'Hôtel Au Bon Coin', 9.4, '5 rue de la cité, 64200 Biarritz, France', "Situé à Biarritz, à 400\xa0mètres du front de mer et de la Grande Plage, l’Hôtel Au Bon Coin propose un bar, un ascenseur, une terrasse et une connex ... (917 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 6402481, 43.4711438, -1.5527266, '2025-11-19', 3.5142857142857147, 15.35, 43.48221, -1.55432),
#  (691, 'Biarritz', 'https://www.booking.com/hotel/fr/biarritz-ocean.fr.html', 'Résidence Biarritz Ocean', 8.5, '10, Rue Etienne Ardoin, 64200 Biarritz, France', "La Résidence Biarritz Océan se situe au cœur de Biarritz, à seulement 400\xa0mètres de la célèbre Grande Plage et à 240\xa0mètres du casino. Cette ré ... (839 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 6402481, 43.4711438, -1.5527266, '2025-11-19', 3.5142857142857147, 15.35, 43.4803, -1.5579),
#  (692, 'Biarritz', 'https://www.booking.com/hotel/fr/altess-hotel.fr.html', 'Hôtel AKENA Biarritz - Grande plage', 8.4, '19 Avenue De La Reine Victoria, 64200 Biarritz, France', "L'Hôtel AKENA Biarritz - Grande plage se trouve à 300 mètres de la plage principale de Biarritz, près du centre-ville. Vous bénéficierez gratuitement ... (507 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 6402481, 43.4711438, -1.5527266, '2025-11-19', 3.5142857142857147, 15.35, 43.48547, -1.55237),
#  (693, 'Biarritz', 'https://www.booking.com/hotel/fr/bel-appartement-bourgeois-au-centre-ville-de-biarritz.fr.html', 'Bel appartement bourgeois au centre-ville de Biarritz', 8.7, '3 Avenue Edouard VII, 64200 Biarritz, France', "Possédant un casino, l’hébergement Bel appartement bourgeois au centre-ville de Biarritz bénéficie d’un emplacement attractif dans le centre de Biarr ... (531 characters truncated) ... he (Aéroport de Biarritz-Pays basque) est à 4 km. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 6402481, 43.4711438, -1.5527266, '2025-11-19', 3.5142857142857147, 15.35, 43.48346, -1.55884),
#  (694, 'Biarritz', 'https://www.booking.com/hotel/fr/thalassa-miramar-biarritz.fr.html', 'Sofitel Biarritz Le Miramar Thalassa', 7.8, '13 rue Louison Bobet, 64200 Biarritz, France', "Situé à quelques pas du centre-ville de Biarritz, le Sofitel Biarritz Le Miramar Thalassa surplombe l'une des plus belles plages de la côte basque. C ... (1284 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 6402481, 43.4711438, -1.5527266, '2025-11-19', 3.5142857142857147, 15.35, 43.48778, -1.55441),
#  (695, 'Biarritz', 'https://www.booking.com/hotel/fr/hotelanjou.fr.html', 'ALFRED HOTELS Les Halles', 9.0, '18, Rue Gambetta, 64200 Biarritz, France', "Entièrement rénové, l'hôtel se compose de 3\xa0maisons de village, de 35\xa0chambres réparties sur 3\xa0étages, et de plateaux au cœur du quartier le ... (571 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 6402481, 43.4711438, -1.5527266, '2025-11-19', 3.5142857142857147, 15.35, 43.48167, -1.56329),
#  (696, 'Biarritz', 'https://www.booking.com/hotel/fr/inter-windsor.fr.html', 'Hôtel Le Windsor Biarritz', 7.9, '11 Avenue Edouard VII, 64200 Biarritz, France', "L’établissement Hôtel Le Windsor Biarritz bénéficie d’une situation géographique idéale dans le centre de Biarritz. Il comprend une connexion Wi-Fi g ... (865 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 6402481, 43.4711438, -1.5527266, '2025-11-19', 3.5142857142857147, 15.35, 43.48395, -1.55849),
#  (697, 'Biarritz', 'https://www.booking.com/hotel/fr/le-garage-regina.fr.html', 'Le Garage Biarritz Hôtel', 9.1, "50 Avenue de l'Impératrice, 64200 Biarritz, France", "Situé en bord de mer, l’établissement Le Garage Biarritz Hôtel propose des hébergements 4 étoiles à Biarritz. Il possède une piscine extérieure ouver ... (1031 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 6402481, 43.4711438, -1.5527266, '2025-11-19', 3.5142857142857147, 15.35, 43.49063, -1.55208),
#  (698, 'Biarritz', 'https://www.booking.com/hotel/fr/eugenie-biarritz.fr.html', 'Hôtel Florida', 7.6, '3-5 place Sainte Eugenie, 64200 Biarritz, France', "Situé en bord de mer à Biarritz, l’Hôtel Florida vous accueille à seulement 300 mètres de la plage. Un petit-déjeuner buffet est servi chaque matin.  ... (779 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 6402481, 43.4711438, -1.5527266, '2025-11-19', 3.5142857142857147, 15.35, 43.48225, -1.56412),
#  (699, 'Biarritz', 'https://www.booking.com/hotel/fr/la-casa-cosy-biarritz.fr.html', "La Casa Cosy, Appart'Hôtel", 8.8, '11 rue Champ Lacombe, 64200 Biarritz, France', "L’établissement La Casa Cosy, Appart'Hôtel se situe dans le centre de Biarritz, à respectivement 500 mètres et 3,2 km de ces lieux d’intérêt : Plage  ... (834 characters truncated) ... s lui donnent la note de   pour un séjour à deux. Les distances indiquées dans la description de l'établissement sont calculées avec © OpenStreetMap.", 6402481, 43.4711438, -1.5527266, '2025-11-19', 3.5142857142857147, 15.35, 43.48031, -1.56255)]

# %% [markdown]
# # ETL wrap-up
#
# With our various services now connected and the extraction part of our ETL process working as expected, time to make the magic work with some SQL alchemy!

# %% [markdown]
# ### Top5 locations

# %%
top5_statement = text("SELECT DISTINCT(place), lat, lon, tw_mean, rainw_mean FROM kayak_project WHERE rainw_mean <= 3 ORDER BY tw_mean DESC LIMIT 5")
top5_connect = engine.connect()
top5_result = top5_connect.execute(top5_statement)
top5_result.fetchall()
# Out:
# 2025-11-19 11:19:05,843 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-19 11:19:05,844 INFO sqlalchemy.engine.Engine SELECT DISTINCT(place), lat, lon, tw_mean, rainw_mean FROM kayak_project WHERE rainw_mean <= 3 ORDER BY tw_mean DESC LIMIT 5
# 2025-11-19 11:19:05,844 INFO sqlalchemy.engine.Engine [cached since 1825s ago] {}
# [('Collioure', 42.52505, 3.0831554, 16.178571428571427, 0.2714285714285714),
#  ('Saintes Maries de la mer', 43.4515922, 4.4277202, 15.335714285714284, 2.3714285714285714),
#  ('Carcassonne', 43.2130358, 2.3491069, 14.37142857142857, 0.0285714285714285),
#  ('Toulouse', 43.6044638, 1.4442433, 13.992857142857144, 0.1571428571428571),
#  ('Montauban', 44.0175835, 1.3549991, 13.62857142857143, 0.1999999999999999)]

# %%
df_top5 = pd.read_sql_query(sql=top5_statement, con=top5_connect)
fig_top5 = px.scatter_map(df_top5, lat="lat", lon="lon", color="tw_mean", hover_name="place", 
                     hover_data=["rainw_mean", "tw_mean"], size="tw_mean", zoom=4)
fig_top5.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig_top5.show()
# Out:
# 2025-11-19 11:19:19,766 INFO sqlalchemy.engine.Engine SELECT DISTINCT(place), lat, lon, tw_mean, rainw_mean FROM kayak_project WHERE rainw_mean <= 3 ORDER BY tw_mean DESC LIMIT 5
# 2025-11-19 11:19:19,767 INFO sqlalchemy.engine.Engine [cached since 1839s ago] {}

# %% [markdown]
# ### Top20 hotels
#
# Since we're using the average weekly temperature for sorting, we can conveniently extract all hotels from the warmest city with a simple LIMIT 20 clause:

# %%
top20_statement = text("SELECT name, url, address, note, lat_h, lon_h, rainw_mean, tw_mean FROM (" \
"SELECT name, url, address, note, lat_h, lon_h, rainw_mean, tw_mean " \
"FROM kayak_project WHERE rainw_mean <= 3) ORDER BY tw_mean DESC LIMIT 20")
top20_connect = engine.connect()
top20_result = top20_connect.execute(top20_statement)
top20_result.fetchall()
# Out:
# 2025-11-19 11:48:21,770 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-19 11:48:21,771 INFO sqlalchemy.engine.Engine SELECT name, url, address, note, lat_h, lon_h, rainw_mean, tw_mean FROM (SELECT name, url, address, note, lat_h, lon_h, rainw_mean, tw_mean FROM kayak_project WHERE rainw_mean <= 3) ORDER BY tw_mean DESC LIMIT 20
# 2025-11-19 11:48:21,772 INFO sqlalchemy.engine.Engine [generated in 0.00248s] {}
# [('66B - Beautiful flat 800m from the sea with private parking', 'https://www.booking.com/hotel/fr/bel-appartement-a-800-m-de-la-mer-parking-prive.fr.html', '27 Rue Romain Rolland, 66190 Collioure, France', 8.9, 42.52803, 3.07775, 0.2714285714285714, 16.178571428571427),
#  ('Le Conflent WIFI Terrace', 'https://www.booking.com/hotel/fr/le-conflent-wifi-terrace.fr.html', '34 Rue du Soleil, 66190 Collioure, France', 8.1, 42.52323, 3.08461, 0.2714285714285714, 16.178571428571427),
#  ('Hôtel Princes de Catalogne', 'https://www.booking.com/hotel/fr/princes-de-catalogne.fr.html', 'Rue Des Palmiers, 66190 Collioure, France', 8.4, 42.52616, 3.0807, 0.2714285714285714, 16.178571428571427),
#  ('Les Suites de Collioure', 'https://www.booking.com/hotel/fr/les-suites-de-collioure.fr.html', '16 avenue du Général de Gaulle, 66190 Collioure, France', 9.3, 42.5244, 3.08273, 0.2714285714285714, 16.178571428571427),
#  ('Résidence St Vincent', 'https://www.booking.com/hotel/fr/residence-saint-vincent.fr.html', '9 rue saint vincent, 66190 Collioure, France', 8.5, 42.52725, 3.08417, 0.2714285714285714, 16.178571428571427),
#  ('Casa Zélie Superbe T4 vue mer, Clim ,Wi-Fi', 'https://www.booking.com/hotel/fr/casa-zelie-superbe-t4-vue-mer-clim-wi-fi.fr.html', '0 11 Route du Pla de las Fourques, 66190 Collioure, France', 10.0, 42.52739, 3.08142, 0.2714285714285714, 16.178571428571427),
#  ('Le Madeloc Hôtel & Spa', 'https://www.booking.com/hotel/fr/madeloc.fr.html', '24 Rue Romain Rolland, 66190 Collioure, France', 9.0, 42.52883, 3.07881, 0.2714285714285714, 16.178571428571427),
#  ('Grand Hotel Du Golfe - Spa & Restaurant', 'https://www.booking.com/hotel/fr/grand-du-golfe.fr.html', '3638 Route De Collioure, 66008 Collioure, France', 8.8, 42.52689, 3.07828, 0.2714285714285714, 16.178571428571427),
#  ('Le Relais Des Trois Mas', 'https://www.booking.com/hotel/fr/le-relais-des-trois-mas.fr.html', 'Route De Port Vendres, 66190 Collioure, France', 9.0, 42.52427, 3.09237, 0.2714285714285714, 16.178571428571427),
#  ('Hotel Méditerranée', 'https://www.booking.com/hotel/fr/mediterranee-collioure.fr.html', 'Avenue Aristide Maillol, 66190 Collioure, France', 8.0, 42.52705, 3.07988, 0.2714285714285714, 16.178571428571427),
#  ('Les Appartements de Collioure', 'https://www.booking.com/hotel/fr/les-appartements-de-collioure.fr.html', '7 Rue Camille Desmoulins, 66190 Collioure, France', 9.2, 42.52366, 3.08397, 0.2714285714285714, 16.178571428571427),
#  ('Canta la Mar - Vue exceptionnelle', 'https://www.booking.com/hotel/fr/studio-canta-la-mar-vue-exceptionnelle.fr.html', '10 Route Impériale, 66190 Collioure, France', 9.4, 42.52452, 3.09055, 0.2714285714285714, 16.178571428571427),
#  ('Residence Pierre & Vacances Les Balcons de Collioure', 'https://www.booking.com/hotel/fr/maevabalconsdecollioure.fr.html', '28, route de Port Vendres, 66190 Collioure, France', 8.2, 42.52502, 3.09038, 0.2714285714285714, 16.178571428571427),
#  ('Studio Centre Plage parking gratuit', 'https://www.booking.com/hotel/fr/studio-centre-plage-collioure.fr.html', '1er Étage 13 Rue Coma Cheric, 66190 Collioure, France', 9.1, 42.52347, 3.08702, 0.2714285714285714, 16.178571428571427),
#  ('Hôtel La Casa Pairal', 'https://www.booking.com/hotel/fr/hotelcasapairal.fr.html', 'Impasse Des Palmiers, 66190 Collioure, France', 9.1, 42.52606, 3.0827, 0.2714285714285714, 16.178571428571427),
#  ('Les Roches Brunes', 'https://www.booking.com/hotel/fr/les-roches-brunes-collioure.fr.html', 'Route de Port-Vendres, 66190 Collioure, France', 9.2, 42.52427, 3.09237, 0.2714285714285714, 16.178571428571427),
#  ('Maison Nova - Boutique Hôtel & Spa', 'https://www.booking.com/hotel/fr/boutique-maison-nova.fr.html', '33 Route du Pla de las Fourques, 66190 Collioure, France', 9.2, 42.5289, 3.07938, 0.2714285714285714, 16.178571428571427),
#  ('La Frégate', 'https://www.booking.com/hotel/fr/la-fra-c-gate-collioure.fr.html', '24 Boulevard Camille Pelletan, 66190 Collioure, France', 8.2, 42.52643, 3.08322, 0.2714285714285714, 16.178571428571427),
#  ('Le Mas des Citronniers', 'https://www.booking.com/hotel/fr/lesmasdescitronniers.fr.html', '22 Avenue de La Republique, 66190 Collioure, France', 8.5, 42.52542, 3.08263, 0.2714285714285714, 16.178571428571427),
#  ("AZUR-Les pieds dans l'eau-Vue sur Mer et Clocher de Collioure en toile de fond - WIFI FIBRE- PARKING Couvert", 'https://www.booking.com/hotel/fr/saphir-collioure.fr.html', '5 Carrer de las Daines, 66190 Collioure, France', 8.6, 42.52396, 3.09662, 0.2714285714285714, 16.178571428571427)]

# %%
df_top20 = pd.read_sql_query(sql=top20_statement, con=top20_connect)
fig_top20 = px.scatter_map(df_top20, lat="lat_h", lon="lon_h", color="note", color_continuous_scale="Turbo",
                     hover_name="name", hover_data=["url", "address"], zoom=14)
fig_top20.update_traces(marker_size=10)
fig_top20.update_layout(map_style="basic", margin={"r":0,"t":0,"l":0,"b":0})
fig_top20.show()
# Out:
# 2025-11-19 11:51:13,081 INFO sqlalchemy.engine.Engine SELECT name, url, address, note, lat_h, lon_h, rainw_mean, tw_mean FROM (SELECT name, url, address, note, lat_h, lon_h, rainw_mean, tw_mean FROM kayak_project WHERE rainw_mean <= 3) ORDER BY tw_mean DESC LIMIT 20
# 2025-11-19 11:51:13,081 INFO sqlalchemy.engine.Engine [cached since 171.3s ago] {}
